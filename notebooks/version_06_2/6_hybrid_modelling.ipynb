# %% [markdown]
# ## Using FEDOT for hybrid modeling with custom model tuning

# %% [markdown]
# #### FEDOT version = 0.6.2

# %%
# !pip install fedot==0.6.2

# %% [markdown]
# [Original repository on GitHub](https://github.com/nccr-itmo/FEDOT)
#
# This tutorial was prepared by [Natural Systems Simulation Team](https://github.com/ITMO-NSS-team)
#
# ---
#
# If you want to learn some basic things about FEDOT and time series forecasting, you can use [this notebook](3_intro_ts_forecasting.ipynb).

# %%
# Additional imports 
import numpy as np
import pandas as pd
from hyperopt import hp
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error

# Imports for creating plots
import matplotlib.pyplot as plt
from pylab import rcParams
rcParams['figure.figsize'] = 18, 7

# Pipeline and nodes
from fedot.core.pipelines.node import PrimaryNode, SecondaryNode
from fedot.core.pipelines.pipeline import Pipeline

# Data
from fedot.core.repository.dataset_types import DataTypesEnum
from fedot.core.data.data import InputData
from fedot.core.data.data_split import train_test_data_setup

# Tasks
from fedot.core.repository.tasks import TaskTypesEnum, Task, TsForecastingParams

#Tuning
from fedot.core.pipelines.tuning.search_space import SearchSpace
from fedot.core.pipelines.tuning.unified import PipelineTuner

import warnings
warnings.filterwarnings('ignore')

import logging
logging.raiseExceptions = False

# %%
# Read the file
df = pd.read_csv('../data/metocean.csv')

plt.plot(np.arange(len(df['value'])), df['value'])
plt.grid()
plt.show()

# Specify forecast length
len_forecast = 50

# Got univariate time series as numpy array
time_series = np.array(df['value'])

# Wrapp data into InputData
task = Task(TaskTypesEnum.ts_forecasting, TsForecastingParams(forecast_length=len_forecast))

# Split data into train and test
train_input, predict_input = train_test_data_setup(InputData(idx=range(len(time_series)),
                                                                 features=time_series,
                                                                 target=time_series,
                                                                 task=Task(TaskTypesEnum.ts_forecasting,
                                                                           TsForecastingParams(forecast_length=len_forecast)),
                                                                 data_type=DataTypesEnum.ts))

# %% [markdown]
# We have a time series of sea level. Based on this time series we will conduct the case of forecasting with custom model implantation in the pipeline.

# %% [markdown]
# ### Custom model specification

# %% [markdown]
# Some custom models have necessary step of fitting, but some of them such as domain specific models doesn't need fitting at all. For using with FEDOT custom model should be wrapped into function that provides fit (if it is necessary) and predict steps. Fit step returns model object, predict step returns predicted values.

# %%
# Let's prepare a function for imitation custom model without fitting
def domain_model_imitation_predict(fitted_model: any, idx: np.array, predict_data: np.array, params: dict):
    a = params.get('a')
    b = params.get('b')
    shape = predict_data.shape
    result = np.random.rand(*shape) * a + b
    # Available output_type's 'table', 'ts', 'image', 'text'
    return result, 'table'

# Function for custom regression model imitation (fit)
def custom_ml_model_imitation_fit(idx: np.array, features: np.array, target: np.array, params: dict):
    alpha = params.get('alpha')
    reg = Ridge(alpha=alpha)
    reg.fit(features, target)
    return reg

# Function for custom regression model imitation (predict)
def custom_ml_model_imitation_predict(fitted_model: any, idx: np.array, features: np.array, params: dict):
    res = fitted_model.predict(features)
    return res, 'table'

# %% [markdown]
# Including custom model into pipeline is provided by using custom parameters of node. Also there should be indicated parameters of model for tune and initial approximation for them.

# %%
# Let's prepare a function for pipeline with custom node without fitting
def get_domain_pipeline():
    """
        Pipeline looking like this
        lagged -> custom -> ridge
    """
    lagged_node = PrimaryNode('lagged')
    lagged_node.parameters = {'window_size': 10}

    # For custom model params as initial approximation and model as function is necessary
    custom_node = SecondaryNode('custom', nodes_from=[lagged_node])
    custom_node.parameters = {"a": -50, "b": 500, 'model_predict': domain_model_imitation_predict}

    node_final = SecondaryNode('ridge', nodes_from=[custom_node])
    pipeline = Pipeline(node_final)

    return pipeline

# Function for pipeline with custom node with fitting
def get_fitting_custom_pipeline():
    """
        Pipeline looking like this
        lagged -> custom -> ridge
    """
    lagged_node = PrimaryNode('lagged')
    lagged_node.parameters = {'window_size': 10}

    # For custom model params as initial approximation and model as function is necessary
    custom_node = SecondaryNode('custom', nodes_from=[lagged_node])
    custom_node.parameters = {'alpha': 5,
                                 'model_predict': custom_ml_model_imitation_predict,
                                 'model_fit': custom_ml_model_imitation_fit}

    node_final = SecondaryNode('lasso', nodes_from=[custom_node])
    pipeline = Pipeline(node_final)

    return pipeline

# %% [markdown]
# For pipeline tuning search space of custom model parameters should be specified. Hyperopt wrapper is used for that.

# %% [markdown]
# ### Function for prediction with/without fitting custom model

# %%
from fedot.core.pipelines.tuning.tuner_builder import TunerBuilder
from fedot.core.pipelines.tuning.unified import PipelineTuner
from fedot.core.repository.quality_metrics_repository import \
    MetricsRepository, RegressionMetricsEnum


def run_pipeline_tuning(pipeline_type):

    if pipeline_type == 'with_fit':
        pipeline = get_fitting_custom_pipeline()
        # Setting custom search space for tuner (necessary)
        # model and output_type should be wrapped into hyperopt
        custom_search_space = {'custom': {
            'alpha': (hp.uniform, [0.01, 10]),
            'model_predict': (hp.choice, [[custom_ml_model_imitation_predict]]),
            'model_fit': (hp.choice, [[custom_ml_model_imitation_fit]])}}
    elif pipeline_type == 'without_fit':
        pipeline = get_domain_pipeline()
        # Setting custom search space for tuner (necessary)
        # model and output_type should be wrapped into hyperopt
        custom_search_space = {'custom': {'a': (hp.uniform, [-100, 100]),
                                          'b': (hp.uniform, [0, 1000]),
                                          'model_predict': (hp.choice, [[domain_model_imitation_predict]])}}
    pipeline.fit_from_scratch(train_input)
    pipeline.print_structure()
    # Get prediction with initial approximation
    predicted_before_tuning = pipeline.predict(predict_input).predict

    replace_default_search_space = True

    # Start tuning all nodes in the pipeline 
    tuner = TunerBuilder(train_input.task)\
            .with_tuner(PipelineTuner)\
            .with_metric(RegressionMetricsEnum.MSE)\
            .with_iterations(50) \
            .with_cv_folds(None) \
            .with_validation_blocks(3) \
            .with_search_space(SearchSpace(custom_search_space=custom_search_space,
                                                                replace_default_search_space=replace_default_search_space))\
            .build(train_input)
    tuned_pipeline = tuner.tune(pipeline)
    
    # Fit pipeline on the entire train data
    pipeline.fit(train_input)
    # Predict tuned pipeline
    predicted_values = pipeline.predict(predict_input).predict
    pipeline.print_structure()

    plt.plot(np.arange(len(predicted_before_tuning[0])), predicted_before_tuning[0], label='Before tuning')
    plt.plot(np.arange(len(predicted_values[0])), predicted_values[0], label='After tuning')
    plt.plot(np.arange(len(predict_input.target)), predict_input.target, label='Real')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ### Case with using model with fitting

# %%
run_pipeline_tuning(pipeline_type='with_fit')
# Out:
# Pipeline structure:
# {'depth': 3, 'length': 3, 'nodes': [lasso, custom, lagged]}
# lasso - {}
# custom - {'alpha': 5, 'model_predict': <function custom_ml_model_imitation_predict at 0x0000020A83C7C3A0>, 'model_fit': <function custom_ml_model_imitation_fit at 0x0000020A83C7C1F0>}
# lagged - {'window_size': 10}
# 2023-02-24 11:30:12,943 - DataSourceSplitter - Hold out validation is applied.
# 2023-02-24 11:30:12,944 - PipelineTuner - Hyperparameters optimization start: estimation of metric for initial pipeline
# 2023-02-24 11:30:13,089 - PipelineTuner - Initial pipeline: {'depth': 3, 'length': 3, 'nodes': [lasso, custom, lagged]}
# lasso - {}
# custom - {'alpha': 5, 'model_predict': <function custom_ml_model_imitation_predict at 0x0000020A83C7C3A0>, 'model_fit': <function custom_ml_model_imitation_fit at 0x0000020A83C7C1F0>}
# lagged - {'window_size': 10}
# Initial metric: 241.516
#   0%|                                                                            | 0/5 [00:00<?, ?trial/s, best loss=?]2023-02-24 11:30:13,095 - build_posterior_wrapper took 0.001001 seconds
# 2023-02-24 11:30:13,097 - TPE using 0 trials
#  20%|██████████▏                                        | 1/5 [00:00<00:00,  8.06trial/s, best loss: 242.1024028324349]2023-02-24 11:30:13,220 - build_posterior_wrapper took 0.001000 seconds
# 2023-02-24 11:30:13,222 - TPE using 1/1 trials with best loss 242.102403
# 2023-02-24 11:30:13,304 - build_posterior_wrapper took 0.000999 seconds
# 2023-02-24 11:30:13,306 - TPE using 2/2 trials with best loss 242.102403
#  60%|██████████████████████████████▌                    | 3/5 [00:00<00:00,  9.85trial/s, best loss: 242.1024028324349]2023-02-24 11:30:13,408 - build_posterior_wrapper took 0.000999 seconds
# 2023-02-24 11:30:13,409 - TPE using 3/3 trials with best loss 242.102403
#  80%|████████████████████████████████████████          | 4/5 [00:00<00:00,  7.64trial/s, best loss: 240.99145557415207]2023-02-24 11:30:13,595 - build_posterior_wrapper took 0.001930 seconds
# 2023-02-24 11:30:13,596 - TPE using 4/4 trials with best loss 240.991456
# 100%|██████████████████████████████████████████████████| 5/5 [00:00<00:00,  8.20trial/s, best loss: 240.99145557415207]
#  10%|███████▌                                                                   | 5/50 [00:00<?, ?trial/s, best loss=?]2023-02-24 11:30:13,709 - build_posterior_wrapper took 0.001994 seconds
# 2023-02-24 11:30:13,710 - TPE using 5/5 trials with best loss 240.991456
# 2023-02-24 11:30:13,714 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 481 to 240.
#  12%|█████▉                                           | 6/50 [00:00<00:14,  3.10trial/s, best loss: 240.99145557415207]2023-02-24 11:30:14,032 - build_posterior_wrapper took 0.001000 seconds
# 2023-02-24 11:30:14,034 - TPE using 6/6 trials with best loss 240.991456
#  14%|██████▊                                          | 7/50 [00:00<00:08,  5.02trial/s, best loss: 240.99145557415207]2023-02-24 11:30:14,146 - build_posterior_wrapper took 0.001986 seconds
# 2023-02-24 11:30:22,248 - TPE using 42/42 trials with best loss 165.660176
#  86%|██████████████████████████████████████████▏      | 43/50 [00:08<00:01,  5.42trial/s, best loss: 165.6601756513094]2023-02-24 11:30:22,413 - build_posterior_wrapper took 0.001011 seconds
# 2023-02-24 11:30:22,414 - TPE using 43/43 trials with best loss 165.660176
# 2023-02-24 11:30:22,424 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 497 to 240.
#  88%|███████████████████████████████████████████      | 44/50 [00:09<00:01,  4.50trial/s, best loss: 165.6601756513094]2023-02-24 11:30:22,731 - build_posterior_wrapper took 0.002013 seconds
# 2023-02-24 11:30:22,732 - TPE using 44/44 trials with best loss 165.660176
# 2023-02-24 11:30:22,815 - build_posterior_wrapper took 0.001129 seconds
# 2023-02-24 11:30:22,816 - TPE using 45/45 trials with best loss 165.214025
# 2023-02-24 11:30:22,826 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 278 to 240.
#  92%|█████████████████████████████████████████████    | 46/50 [00:09<00:00,  4.33trial/s, best loss: 165.2140246915824]2023-02-24 11:30:23,214 - build_posterior_wrapper took 0.001547 seconds
# 2023-02-24 11:30:23,215 - TPE using 46/46 trials with best loss 165.214025
#  94%|██████████████████████████████████████████████   | 47/50 [00:09<00:00,  4.83trial/s, best loss: 165.2140246915824]2023-02-24 11:30:23,346 - build_posterior_wrapper took 0.001152 seconds
# 2023-02-24 11:30:23,347 - TPE using 47/47 trials with best loss 165.214025
#  96%|███████████████████████████████████████████████  | 48/50 [00:09<00:00,  4.55trial/s, best loss: 165.2140246915824]2023-02-24 11:30:23,602 - build_posterior_wrapper took 0.000998 seconds
# 2023-02-24 11:30:23,603 - TPE using 48/48 trials with best loss 165.214025
# 2023-02-24 11:30:23,614 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 460 to 240.
#  98%|████████████████████████████████████████████████ | 49/50 [00:10<00:00,  4.01trial/s, best loss: 165.2140246915824]2023-02-24 11:30:23,931 - build_posterior_wrapper took 0.001000 seconds
# 2023-02-24 11:30:23,932 - TPE using 49/49 trials with best loss 165.214025
# 100%|█████████████████████████████████████████████████| 50/50 [00:10<00:00,  4.28trial/s, best loss: 165.2140246915824]
# 2023-02-24 11:30:24,305 - PipelineTuner - Hyperparameters optimization finished
# 2023-02-24 11:30:24,306 - PipelineTuner - Return tuned pipeline due to the fact that obtained metric 165.214 equal or better than initial (+ 0.05% deviation) 241.395
# 2023-02-24 11:30:24,307 - PipelineTuner - Final pipeline: {'depth': 3, 'length': 3, 'nodes': [lasso, custom, lagged]}
# lasso - {'alpha': 5.43409465776688}
# custom - {'alpha': 6.362843506702346, 'model_fit': <function custom_ml_model_imitation_fit at 0x0000020A83C7C1F0>, 'model_predict': <function custom_ml_model_imitation_predict at 0x0000020A83C7C3A0>}
# lagged - {'window_size': 31}
# 2023-02-24 11:30:24,307 - PipelineTuner - Final metric: 165.214
# Pipeline structure:
# {'depth': 3, 'length': 3, 'nodes': [lasso, custom, lagged]}
# lasso - {'alpha': 5.43409465776688}
# custom - {'alpha': 6.362843506702346, 'model_fit': <function custom_ml_model_imitation_fit at 0x0000020A83C7C1F0>, 'model_predict': <function custom_ml_model_imitation_predict at 0x0000020A83C7C3A0>}
# lagged - {'window_size': 31}

# %%
run_pipeline_tuning(pipeline_type='without_fit')
# Out:
# Pipeline structure:
# {'depth': 3, 'length': 3, 'nodes': [ridge, custom, lagged]}
# ridge - {}
# custom - {'a': -50, 'b': 500, 'model_predict': <function domain_model_imitation_predict at 0x0000020A48A709D0>}
# lagged - {'window_size': 10}
# 2023-02-24 11:30:24,613 - DataSourceSplitter - Hold out validation is applied.
# 2023-02-24 11:30:24,614 - PipelineTuner - Hyperparameters optimization start: estimation of metric for initial pipeline
# 2023-02-24 11:30:24,663 - PipelineTuner - Initial pipeline: {'depth': 3, 'length': 3, 'nodes': [ridge, custom, lagged]}
# ridge - {}
# custom - {'a': -50, 'b': 500, 'model_predict': <function domain_model_imitation_predict at 0x0000020A48A709D0>}
# lagged - {'window_size': 10}
# Initial metric: 38850.116
#   0%|                                                                            | 0/5 [00:00<?, ?trial/s, best loss=?]2023-02-24 11:30:24,669 - build_posterior_wrapper took 0.001999 seconds
# 2023-02-24 11:30:24,669 - TPE using 0 trials
# 2023-02-24 11:30:24,719 - build_posterior_wrapper took 0.000999 seconds
# 2023-02-24 11:30:24,720 - TPE using 1/1 trials with best loss 46360.100629
#  40%|████████████████████▍                              | 2/5 [00:00<00:00, 19.92trial/s, best loss: 46360.10062907752]2023-02-24 11:30:24,770 - build_posterior_wrapper took 0.001000 seconds
# 2023-02-24 11:30:24,771 - TPE using 2/2 trials with best loss 46360.100629
# 2023-02-24 11:30:24,820 - build_posterior_wrapper took 0.001001 seconds
# 2023-02-24 11:30:24,821 - TPE using 3/3 trials with best loss 32910.286786
#  80%|████████████████████████████████████████          | 4/5 [00:00<00:00, 19.51trial/s, best loss: 32910.286786416844]2023-02-24 11:30:24,874 - build_posterior_wrapper took 0.001005 seconds
# 2023-02-24 11:30:24,875 - TPE using 4/4 trials with best loss 32910.286786
# 100%|██████████████████████████████████████████████████| 5/5 [00:00<00:00, 19.65trial/s, best loss: 32910.286786416844]
#  10%|███████▌                                                                   | 5/50 [00:00<?, ?trial/s, best loss=?]2023-02-24 11:30:24,928 - build_posterior_wrapper took 0.000988 seconds
# 2023-02-24 11:30:24,930 - TPE using 5/5 trials with best loss 32910.286786
# 2023-02-24 11:30:25,003 - build_posterior_wrapper took 0.001001 seconds
# 2023-02-24 11:30:25,004 - TPE using 6/6 trials with best loss 30726.606227
# 2023-02-24 11:30:25,008 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 428 to 240.
#  14%|███████                                           | 7/50 [00:00<00:08,  5.37trial/s, best loss: 9983.237307291918]2023-02-24 11:30:25,301 - build_posterior_wrapper took 0.001005 seconds
# 2023-02-24 11:30:25,302 - TPE using 7/7 trials with best loss 9983.237307
#  16%|████████▏                                          | 8/50 [00:00<00:07,  5.30trial/s, best loss: 5941.93650741053]2023-02-24 11:30:25,493 - build_posterior_wrapper took 0.000808 seconds
# 2023-02-24 11:30:25,494 - TPE using 8/8 trials with best loss 5941.936507
# 2023-02-24 11:30:25,498 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 435 to 240.
#  18%|█████████▏                                         | 9/50 [00:00<00:10,  3.85trial/s, best loss: 5941.93650741053]2023-02-24 11:30:25,874 - build_posterior_wrapper took 0.001553 seconds
# 2023-02-24 11:30:25,874 - TPE using 9/9 trials with best loss 5941.936507
# 2023-02-24 11:30:25,877 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 292 to 240.
#  20%|██████████                                        | 10/50 [00:01<00:10,  3.71trial/s, best loss: 5941.93650741053]2023-02-24 11:30:26,162 - build_posterior_wrapper took 0.002006 seconds
# 2023-02-24 11:30:26,162 - TPE using 10/10 trials with best loss 5941.936507
# 2023-02-24 11:30:26,256 - build_posterior_wrapper took 0.001000 seconds
# 2023-02-24 11:30:26,257 - TPE using 11/11 trials with best loss 5941.936507
# 2023-02-24 11:30:26,261 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 473 to 240.
#  24%|████████████                                      | 12/50 [00:01<00:08,  4.30trial/s, best loss: 5941.93650741053]2023-02-24 11:30:26,551 - build_posterior_wrapper took 0.001005 seconds
# 2023-02-24 11:30:26,551 - TPE using 12/12 trials with best loss 5941.936507
# 2023-02-24 11:30:26,556 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 375 to 240.
#  26%|█████████████                                     | 13/50 [00:01<00:09,  4.02trial/s, best loss: 5036.90362247122]2023-02-24 11:30:26,847 - build_posterior_wrapper took 0.001002 seconds
# 2023-02-24 11:30:26,849 - TPE using 13/13 trials with best loss 5036.903622
# 2023-02-24 11:30:26,918 - build_posterior_wrapper took 0.001000 seconds
# 2023-02-24 11:30:26,919 - TPE using 14/14 trials with best loss 5036.903622
#  30%|███████████████                                   | 15/50 [00:02<00:06,  5.16trial/s, best loss: 5036.90362247122]2023-02-24 11:30:27,089 - build_posterior_wrapper took 0.001995 seconds
# 2023-02-24 11:30:27,090 - TPE using 15/15 trials with best loss 5036.903622
# 2023-02-24 11:30:27,093 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 483 to 240.
#  32%|████████████████▎                                  | 16/50 [00:02<00:07,  4.53trial/s, best loss: 591.11704221822]2023-02-24 11:30:27,396 - build_posterior_wrapper took 0.002005 seconds
# 2023-02-24 11:30:27,397 - TPE using 16/16 trials with best loss 591.117042
# 2023-02-24 11:30:27,463 - build_posterior_wrapper took 0.000991 seconds
# 2023-02-24 11:30:27,464 - TPE using 17/17 trials with best loss 591.117042
# 2023-02-24 11:30:27,467 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 294 to 240.
#  36%|██████████████████▎                                | 18/50 [00:02<00:07,  4.47trial/s, best loss: 591.11704221822]2023-02-24 11:30:27,851 - build_posterior_wrapper took 0.001993 seconds
# 2023-02-24 11:30:27,851 - TPE using 18/18 trials with best loss 591.117042
# 2023-02-24 11:30:27,854 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 267 to 240.
#  38%|███████████████████▍                               | 19/50 [00:03<00:07,  4.01trial/s, best loss: 591.11704221822]2023-02-24 11:30:28,192 - build_posterior_wrapper took 0.002003 seconds
# 2023-02-24 11:30:28,193 - TPE using 19/19 trials with best loss 591.117042
# 2023-02-24 11:30:28,196 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 278 to 240.
#  40%|████████████████████▍                              | 20/50 [00:03<00:07,  3.78trial/s, best loss: 591.11704221822]2023-02-24 11:30:28,504 - build_posterior_wrapper took 0.001000 seconds
# 2023-02-24 11:30:28,505 - TPE using 20/20 trials with best loss 591.117042
#  42%|█████████████████████▍                             | 21/50 [00:03<00:07,  3.89trial/s, best loss: 591.11704221822]2023-02-24 11:30:28,739 - build_posterior_wrapper took 0.002007 seconds
# 2023-02-24 11:30:28,739 - TPE using 21/21 trials with best loss 591.117042
# 2023-02-24 11:30:28,749 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 499 to 240.
#  44%|██████████████████████▍                            | 22/50 [00:04<00:07,  3.66trial/s, best loss: 591.11704221822]2023-02-24 11:30:29,058 - build_posterior_wrapper took 0.001004 seconds
# 2023-02-24 11:30:29,058 - TPE using 22/22 trials with best loss 591.117042
# 2023-02-24 11:30:29,069 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 330 to 240.
#  46%|███████████████████████▍                           | 23/50 [00:04<00:07,  3.52trial/s, best loss: 591.11704221822]2023-02-24 11:30:29,368 - build_posterior_wrapper took 0.001000 seconds
# 2023-02-24 11:30:29,369 - TPE using 23/23 trials with best loss 591.117042
#  48%|███████████████████████▌                         | 24/50 [00:04<00:08,  3.16trial/s, best loss: 533.9222647608327]2023-02-24 11:30:29,765 - build_posterior_wrapper took 0.001000 seconds
# 2023-02-24 11:30:29,766 - TPE using 24/24 trials with best loss 533.922265
#  50%|████████████████████████                        | 25/50 [00:05<00:07,  3.30trial/s, best loss: 496.36891911231294]2023-02-24 11:30:30,036 - build_posterior_wrapper took 0.000997 seconds
# 2023-02-24 11:30:30,038 - TPE using 25/25 trials with best loss 496.368919
#  52%|████████████████████████▉                       | 26/50 [00:05<00:07,  3.39trial/s, best loss: 496.36891911231294]2023-02-24 11:30:30,311 - build_posterior_wrapper took 0.001008 seconds
# 2023-02-24 11:30:30,312 - TPE using 26/26 trials with best loss 496.368919
#  54%|█████████████████████████▉                      | 27/50 [00:05<00:05,  4.04trial/s, best loss: 496.36891911231294]2023-02-24 11:30:30,444 - build_posterior_wrapper took 0.000987 seconds
# 2023-02-24 11:30:30,445 - TPE using 27/27 trials with best loss 496.368919
#  56%|██████████████████████████▉                     | 28/50 [00:05<00:05,  3.85trial/s, best loss: 496.36891911231294]2023-02-24 11:30:30,733 - build_posterior_wrapper took 0.001000 seconds
# 2023-02-24 11:30:30,734 - TPE using 28/28 trials with best loss 496.368919
#  58%|███████████████████████████▊                    | 29/50 [00:06<00:05,  3.76trial/s, best loss: 496.36891911231294]2023-02-24 11:30:31,014 - build_posterior_wrapper took 0.001001 seconds
# 2023-02-24 11:30:31,014 - TPE using 29/29 trials with best loss 496.368919
#  60%|████████████████████████████▊                   | 30/50 [00:06<00:04,  4.35trial/s, best loss: 496.36891911231294]2023-02-24 11:30:31,160 - build_posterior_wrapper took 0.001998 seconds
# 2023-02-24 11:30:31,160 - TPE using 30/30 trials with best loss 496.368919
# 2023-02-24 11:30:31,214 - build_posterior_wrapper took 0.000999 seconds
# 2023-02-24 11:30:31,215 - TPE using 31/31 trials with best loss 496.368919
# 2023-02-24 11:30:31,226 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 339 to 240.
#  64%|██████████████████████████████▋                 | 32/50 [00:06<00:03,  4.82trial/s, best loss: 496.36891911231294]2023-02-24 11:30:31,521 - build_posterior_wrapper took 0.000999 seconds
# 2023-02-24 11:30:31,522 - TPE using 32/32 trials with best loss 496.368919
#  66%|███████████████████████████████▋                | 33/50 [00:06<00:03,  4.29trial/s, best loss: 496.36891911231294]2023-02-24 11:30:31,832 - build_posterior_wrapper took 0.001000 seconds
# 2023-02-24 11:30:31,833 - TPE using 33/33 trials with best loss 496.368919
# 2023-02-24 11:30:31,843 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 359 to 240.
#  68%|████████████████████████████████▋               | 34/50 [00:07<00:04,  3.94trial/s, best loss: 496.36891911231294]2023-02-24 11:30:32,144 - build_posterior_wrapper took 0.001005 seconds
# 2023-02-24 11:30:32,146 - TPE using 34/34 trials with best loss 496.368919
#  70%|█████████████████████████████████▌              | 35/50 [00:07<00:03,  4.41trial/s, best loss: 496.36891911231294]2023-02-24 11:30:32,299 - build_posterior_wrapper took 0.001000 seconds
# 2023-02-24 11:30:32,299 - TPE using 35/35 trials with best loss 496.368919
#  72%|██████████████████████████████████▌             | 36/50 [00:07<00:03,  3.98trial/s, best loss: 496.36891911231294]2023-02-24 11:30:32,614 - build_posterior_wrapper took 0.001001 seconds
# 2023-02-24 11:30:32,615 - TPE using 36/36 trials with best loss 496.368919
# 2023-02-24 11:30:32,625 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 306 to 240.
#  74%|███████████████████████████████████▌            | 37/50 [00:07<00:03,  3.73trial/s, best loss: 496.36891911231294]2023-02-24 11:30:32,924 - build_posterior_wrapper took 0.001008 seconds
# 2023-02-24 11:30:32,925 - TPE using 37/37 trials with best loss 496.368919
#  76%|████████████████████████████████████▍           | 38/50 [00:08<00:02,  4.53trial/s, best loss: 496.36891911231294]2023-02-24 11:30:33,028 - build_posterior_wrapper took 0.001008 seconds
# 2023-02-24 11:30:33,029 - TPE using 38/38 trials with best loss 496.368919
# 2023-02-24 11:30:33,039 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 410 to 240.
#  78%|█████████████████████████████████████▍          | 39/50 [00:08<00:02,  4.03trial/s, best loss: 496.36891911231294]2023-02-24 11:30:33,343 - build_posterior_wrapper took 0.002003 seconds
# 2023-02-24 11:30:33,344 - TPE using 39/39 trials with best loss 496.368919
#  80%|██████████████████████████████████████▍         | 40/50 [00:08<00:02,  3.93trial/s, best loss: 496.36891911231294]2023-02-24 11:30:33,611 - build_posterior_wrapper took 0.001010 seconds
# 2023-02-24 11:30:33,612 - TPE using 40/40 trials with best loss 496.368919
#  82%|███████████████████████████████████████▎        | 41/50 [00:08<00:02,  4.24trial/s, best loss: 496.36891911231294]2023-02-24 11:30:33,805 - build_posterior_wrapper took 0.002002 seconds
# 2023-02-24 11:30:33,808 - TPE using 41/41 trials with best loss 496.368919
#  84%|████████████████████████████████████████▎       | 42/50 [00:09<00:01,  4.91trial/s, best loss: 496.36891911231294]2023-02-24 11:30:33,932 - build_posterior_wrapper took 0.002000 seconds
# 2023-02-24 11:30:33,932 - TPE using 42/42 trials with best loss 496.368919
# 2023-02-24 11:30:33,943 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 259 to 240.
#  86%|█████████████████████████████████████████▎      | 43/50 [00:09<00:01,  3.70trial/s, best loss: 496.36891911231294]2023-02-24 11:30:34,357 - build_posterior_wrapper took 0.001001 seconds
# 2023-02-24 11:30:34,359 - TPE using 43/43 trials with best loss 496.368919
# 2023-02-24 11:30:34,371 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 313 to 240.
#  88%|██████████████████████████████████████████▏     | 44/50 [00:09<00:01,  3.30trial/s, best loss: 496.36891911231294]2023-02-24 11:30:34,739 - build_posterior_wrapper took 0.000999 seconds
# 2023-02-24 11:30:34,740 - TPE using 44/44 trials with best loss 496.368919
#  90%|███████████████████████████████████████████▏    | 45/50 [00:10<00:01,  3.70trial/s, best loss: 496.36891911231294]2023-02-24 11:30:34,932 - build_posterior_wrapper took 0.001006 seconds
# 2023-02-24 11:30:34,933 - TPE using 45/45 trials with best loss 496.368919
# 2023-02-24 11:30:34,944 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 449 to 240.
#  92%|████████████████████████████████████████████▏   | 46/50 [00:10<00:01,  3.51trial/s, best loss: 496.36891911231294]2023-02-24 11:30:35,251 - build_posterior_wrapper took 0.001002 seconds
# 2023-02-24 11:30:35,252 - TPE using 46/46 trials with best loss 496.368919
# 2023-02-24 11:30:35,310 - build_posterior_wrapper took 0.000993 seconds
# 2023-02-24 11:30:35,311 - TPE using 47/47 trials with best loss 496.368919
# 2023-02-24 11:30:35,322 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 406 to 240.
#  96%|██████████████████████████████████████████████  | 48/50 [00:10<00:00,  3.99trial/s, best loss: 496.36891911231294]2023-02-24 11:30:35,672 - build_posterior_wrapper took 0.001000 seconds
# 2023-02-24 11:30:35,673 - TPE using 48/48 trials with best loss 496.368919
#  98%|███████████████████████████████████████████████ | 49/50 [00:10<00:00,  4.65trial/s, best loss: 496.36891911231294]2023-02-24 11:30:35,778 - build_posterior_wrapper took 0.001006 seconds
# 2023-02-24 11:30:35,779 - TPE using 49/49 trials with best loss 496.368919
# 2023-02-24 11:30:35,790 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 354 to 240.
# 100%|████████████████████████████████████████████████| 50/50 [00:11<00:00,  4.03trial/s, best loss: 496.36891911231294]
# 2023-02-24 11:30:36,481 - PipelineTuner - Hyperparameters optimization finished
# 2023-02-24 11:30:36,482 - PipelineTuner - Return tuned pipeline due to the fact that obtained metric 495.893 equal or better than initial (+ 0.05% deviation) 38830.691
# 2023-02-24 11:30:36,483 - PipelineTuner - Final pipeline: {'depth': 3, 'length': 3, 'nodes': [ridge, custom, lagged]}
# ridge - {'alpha': 6.590651023353968}
# custom - {'a': -8.776146179870658, 'b': 89.47931668156521, 'model_predict': <function domain_model_imitation_predict at 0x0000020A48A709D0>}
# lagged - {'window_size': 218}
# 2023-02-24 11:30:36,484 - PipelineTuner - Final metric: 495.893
# Pipeline structure:
# {'depth': 3, 'length': 3, 'nodes': [ridge, custom, lagged]}
# ridge - {'alpha': 6.590651023353968}
# custom - {'a': -8.776146179870658, 'b': 89.47931668156521, 'model_predict': <function domain_model_imitation_predict at 0x0000020A48A709D0>}
# lagged - {'window_size': 218}

# %% [markdown]
# Thus, we demonstrated the use of imitation of custom model with FEDOT for providing the hybrid approach in composition with AutoML.
