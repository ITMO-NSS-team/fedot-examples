# %% [markdown]
# ## Using FEDOT for hybrid modeling with custom model tuning

# %% [markdown]
# #### FEDOT version = 0.7.2

# %%
# !pip install fedot==0.7.2

# %% [markdown]
# [Original repository on GitHub](https://github.com/nccr-itmo/FEDOT)
#
# This tutorial was prepared by [Natural Systems Simulation Team](https://github.com/ITMO-NSS-team)
#
# ---
#
# If you want to learn some basic things about FEDOT and time series forecasting, you can use [this notebook](3_intro_ts_forecasting.ipynb).

# %%
# Additional imports 
import numpy as np
import pandas as pd
from hyperopt import hp
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error

# Imports for creating plots
import matplotlib.pyplot as plt
from pylab import rcParams
rcParams['figure.figsize'] = 18, 7

# Pipeline and nodes
from fedot.core.pipelines.node import PrimaryNode, SecondaryNode
from fedot.core.pipelines.pipeline import Pipeline

# Data
from fedot.core.repository.dataset_types import DataTypesEnum
from fedot.core.data.data import InputData
from fedot.core.data.data_split import train_test_data_setup

# Tasks
from fedot.core.repository.tasks import TaskTypesEnum, Task, TsForecastingParams

#Tuning
from fedot.core.pipelines.tuning.search_space import PipelineSearchSpace
from golem.core.tuning.simultaneous import SimultaneousTuner

import warnings
warnings.filterwarnings('ignore')

import logging
logging.raiseExceptions = False

# %%
# Read the file
df = pd.read_csv('../data/metocean.csv')

plt.plot(np.arange(len(df['value'])), df['value'])
plt.grid()
plt.show()

# Specify forecast length
len_forecast = 50

# Got univariate time series as numpy array
time_series = np.array(df['value'])

# Wrapp data into InputData
task = Task(TaskTypesEnum.ts_forecasting, TsForecastingParams(forecast_length=len_forecast))

# Split data into train and test
train_input, predict_input = train_test_data_setup(InputData(idx=range(len(time_series)),
                                                                 features=time_series,
                                                                 target=time_series,
                                                                 task=Task(TaskTypesEnum.ts_forecasting,
                                                                           TsForecastingParams(forecast_length=len_forecast)),
                                                                 data_type=DataTypesEnum.ts))

# %% [markdown]
# We have a time series of sea level. Based on this time series we will conduct the case of forecasting with custom model implantation in the pipeline.

# %% [markdown]
# ### Custom model specification

# %% [markdown]
# Some custom models have necessary step of fitting, but some of them such as domain specific models doesn't need fitting at all. For using with FEDOT custom model should be wrapped into function that provides fit (if it is necessary) and predict steps. Fit step returns model object, predict step returns predicted values.

# %%
# Let's prepare a function for imitation custom model without fitting
def domain_model_imitation_predict(fitted_model: any, idx: np.array, predict_data: np.array, params: dict):
    a = params.get('a')
    b = params.get('b')
    shape = predict_data.shape
    result = np.random.rand(*shape) * a + b
    # Available output_type's 'table', 'ts', 'image', 'text'
    return result, 'table'

# Function for custom regression model imitation (fit)
def custom_ml_model_imitation_fit(idx: np.array, features: np.array, target: np.array, params: dict):
    alpha = params.get('alpha')
    reg = Ridge(alpha=alpha)
    reg.fit(features, target)
    return reg

# Function for custom regression model imitation (predict)
def custom_ml_model_imitation_predict(fitted_model: any, idx: np.array, features: np.array, params: dict):
    res = fitted_model.predict(features)
    return res, 'table'

# %% [markdown]
# Including custom model into pipeline is provided by using custom parameters of node. Also there should be indicated parameters of model for tune and initial approximation for them.

# %%
# Let's prepare a function for pipeline with custom node without fitting
def get_domain_pipeline():
    """
        Pipeline looking like this
        lagged -> custom -> ridge
    """
    lagged_node = PrimaryNode('lagged')
    lagged_node.parameters = {'window_size': 10}

    # For custom model params as initial approximation and model as function is necessary
    custom_node = SecondaryNode('custom', nodes_from=[lagged_node])
    custom_node.parameters = {"a": -50, "b": 500, 'model_predict': domain_model_imitation_predict}

    node_final = SecondaryNode('ridge', nodes_from=[custom_node])
    pipeline = Pipeline(node_final)

    return pipeline

# Function for pipeline with custom node with fitting
def get_fitting_custom_pipeline():
    """
        Pipeline looking like this
        lagged -> custom -> ridge
    """
    lagged_node = PrimaryNode('lagged')
    lagged_node.parameters = {'window_size': 10}

    # For custom model params as initial approximation and model as function is necessary
    custom_node = SecondaryNode('custom', nodes_from=[lagged_node])
    custom_node.parameters = {'alpha': 5,
                                 'model_predict': custom_ml_model_imitation_predict,
                                 'model_fit': custom_ml_model_imitation_fit}

    node_final = SecondaryNode('lasso', nodes_from=[custom_node])
    pipeline = Pipeline(node_final)

    return pipeline

# %% [markdown]
# For pipeline tuning search space of custom model parameters should be specified. Hyperopt wrapper is used for that.

# %% [markdown]
# ### Function for prediction with/without fitting custom model

# %%
from fedot.core.pipelines.tuning.tuner_builder import TunerBuilder
from fedot.core.repository.quality_metrics_repository import \
    MetricsRepository, RegressionMetricsEnum


def run_pipeline_tuning(pipeline_type):

    if pipeline_type == 'with_fit':
        pipeline = get_fitting_custom_pipeline()
        # Setting custom search space for tuner (necessary)
        # model and output_type should be wrapped into hyperopt
        custom_search_space = {
            'custom': {
                'alpha': {
                    'hyperopt-dist': hp.uniform,
                    'sampling-scope': [0.01, 10],
                    'type': 'continuous'
                },
                'model_predict': {
                    'hyperopt-dist': hp.choice,
                    'sampling-scope': [[custom_ml_model_imitation_predict]],
                    'type': 'categorical'
                },
                'model_fit': {
                    'hyperopt-dist': hp.choice,
                    'sampling-scope': [[custom_ml_model_imitation_fit]],
                    'type': 'categorical'
                }
            }
        }
    elif pipeline_type == 'without_fit':
        pipeline = get_domain_pipeline()
        # Setting custom search space for tuner (necessary)
        # model and output_type should be wrapped into hyperopt
        custom_search_space = {
            'custom': {
                'a': {
                    'hyperopt-dist': hp.uniform,
                    'sampling-scope': [-100, 100],
                    'type': 'discrete'
                },
                'b': {
                    'hyperopt-dist': hp.uniform,
                    'sampling-scope': [0, 1000],
                    'type': 'discrete'
                },
                'model_predict': {
                    'hyperopt-dist': hp.choice,
                    'sampling-scope': [[domain_model_imitation_predict]],
                    'type': 'categorical'
                }
            }
        }
    pipeline.fit_from_scratch(train_input)
    pipeline.print_structure()
    # Get prediction with initial approximation
    predicted_before_tuning = pipeline.predict(predict_input).predict

    replace_default_search_space = True

    # Start tuning all nodes in the pipeline 
    tuner = (
        TunerBuilder(train_input.task)
            .with_tuner(SimultaneousTuner)
            .with_metric(RegressionMetricsEnum.MSE)
            .with_iterations(50)
            .with_cv_folds(None)
            .with_validation_blocks(3)
            .with_search_space(PipelineSearchSpace(custom_search_space=custom_search_space,
                                                   replace_default_search_space=replace_default_search_space))
            .build(train_input)
    )
    tuned_pipeline = tuner.tune(pipeline)
    
    # Fit pipeline on the entire train data
    pipeline.fit(train_input)
    # Predict tuned pipeline
    predicted_values = pipeline.predict(predict_input).predict
    pipeline.print_structure()
    return predicted_before_tuning, predicted_values, predict_input.target

def plot_results(predicted_before_tuning, predicted_values, target):
    plt.plot(np.arange(len(predicted_before_tuning[0])), predicted_before_tuning[0], label='Before tuning')
    plt.plot(np.arange(len(predicted_values[0])), predicted_values[0], label='After tuning')
    plt.plot(np.arange(len(target)), target, label='Real')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ### Case with using model with fitting

# %%
predicted_before_tuning, predicted_values, target = run_pipeline_tuning(pipeline_type='with_fit')
# Out:
# Pipeline structure:
# {'depth': 3, 'length': 3, 'nodes': [lasso, custom, lagged]}
# lasso - {}
# custom - {'alpha': 5, 'model_predict': <function custom_ml_model_imitation_predict at 0x000002689F6A99D0>, 'model_fit': <function custom_ml_model_imitation_fit at 0x000002689F6A9940>}
# lagged - {'window_size': 10}
# 2023-10-06 10:33:04,774 - DataSourceSplitter - Hold out validation is applied.
# 2023-10-06 10:33:04,776 - SimultaneousTuner - Hyperparameters optimization start: estimation of metric for initial graph
# 2023-10-06 10:33:05,023 - SimultaneousTuner - Initial graph: {'depth': 3, 'length': 3, 'nodes': [lasso, custom, lagged]}
# lasso - {}
# custom - {'alpha': 5, 'model_predict': <function custom_ml_model_imitation_predict at 0x000002689F6A99D0>, 'model_fit': <function custom_ml_model_imitation_fit at 0x000002689F6A9940>}
# lagged - {'window_size': 10}
# Initial metric: [241.516]
#   0%|          | 0/5 [00:00<?, ?trial/s, best loss=?]2023-10-06 10:33:05,030 - build_posterior_wrapper took 0.001998 seconds
# 2023-10-06 10:33:05,031 - TPE using 0 trials
#  20%|██        | 1/5 [00:00<00:00,  5.61trial/s, best loss: 242.86422554605878]2023-10-06 10:33:05,209 - build_posterior_wrapper took 0.001999 seconds
# 2023-10-06 10:33:05,210 - TPE using 1/1 trials with best loss 242.864226
#  40%|████      | 2/5 [00:00<00:00,  6.01trial/s, best loss: 242.86422554605878]2023-10-06 10:33:05,367 - build_posterior_wrapper took 0.001997 seconds
# 2023-10-06 10:33:05,368 - TPE using 2/2 trials with best loss 242.864226
#  60%|██████    | 3/5 [00:00<00:00,  6.24trial/s, best loss: 242.86422554605878]2023-10-06 10:33:05,520 - build_posterior_wrapper took 0.001997 seconds
# 2023-10-06 10:33:05,521 - TPE using 3/3 trials with best loss 242.864226
#  80%|████████  | 4/5 [00:00<00:00,  6.12trial/s, best loss: 242.86422554605878]2023-10-06 10:33:05,689 - build_posterior_wrapper took 0.001997 seconds
# 2023-10-06 10:33:05,691 - TPE using 4/4 trials with best loss 242.864226
# 100%|██████████| 5/5 [00:00<00:00,  6.25trial/s, best loss: 242.86422554605878]
#  10%|█         | 5/50 [00:00<?, ?trial/s, best loss=?]2023-10-06 10:33:05,834 - build_posterior_wrapper took 0.001998 seconds
# 2023-10-06 10:33:05,835 - TPE using 5/5 trials with best loss 242.864226
#  12%|█▏        | 6/50 [00:00<00:10,  4.08trial/s, best loss: 242.86422554605878]2023-10-06 10:33:06,080 - build_posterior_wrapper took 0.001998 seconds
# 2023-10-06 10:33:06,081 - TPE using 6/6 trials with best loss 242.864226
#  14%|█▍        | 7/50 [00:00<00:19,  2.17trial/s, best loss: 242.86422554605878]2023-10-06 10:33:06,693 - build_posterior_wrapper took 0.001998 seconds
# 2023-10-06 10:33:06,694 - TPE using 7/7 trials with best loss 242.864226
# 2023-10-06 10:33:06,699 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 369 to 240.
#  16%|█▌        | 8/50 [00:01<00:25,  1.67trial/s, best loss: 242.86422554605878]2023-10-06 10:33:07,452 - build_posterior_wrapper took 0.001997 seconds
# 2023-10-06 10:33:07,454 - TPE using 8/8 trials with best loss 242.864226
#  18%|█▊        | 9/50 [00:01<00:17,  2.31trial/s, best loss: 242.86422554605878]2023-10-06 10:33:07,635 - build_posterior_wrapper took 0.002000 seconds
# 2023-10-06 10:33:07,637 - TPE using 9/9 trials with best loss 242.864226
# 2023-10-06 10:33:07,642 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 322 to 240.
#  20%|██        | 10/50 [00:02<00:20,  1.93trial/s, best loss: 242.86422554605878]2023-10-06 10:33:08,300 - build_posterior_wrapper took 0.001997 seconds
# 2023-10-06 10:33:08,301 - TPE using 10/10 trials with best loss 242.864226
# 2023-10-06 10:33:08,306 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from
- build_posterior_wrapper took 0.002000 seconds
# 2023-10-06 10:33:21,828 - TPE using 40/40 trials with best loss 164.437247
#  82%|████████▏ | 41/50 [00:16<00:03,  2.66trial/s, best loss: 164.43724697712824]2023-10-06 10:33:22,150 - build_posterior_wrapper took 0.001998 seconds
# 2023-10-06 10:33:22,151 - TPE using 41/41 trials with best loss 164.437247
#  84%|████████▍ | 42/50 [00:16<00:02,  3.02trial/s, best loss: 164.43724697712824]2023-10-06 10:33:22,376 - build_posterior_wrapper took 0.002005 seconds
# 2023-10-06 10:33:22,377 - TPE using 42/42 trials with best loss 164.437247
#  86%|████████▌ | 43/50 [00:17<00:02,  2.37trial/s, best loss: 164.43724697712824]2023-10-06 10:33:23,010 - build_posterior_wrapper took 0.001999 seconds
# 2023-10-06 10:33:23,011 - TPE using 43/43 trials with best loss 164.437247
#  88%|████████▊ | 44/50 [00:17<00:02,  2.28trial/s, best loss: 164.43724697712824]2023-10-06 10:33:23,490 - build_posterior_wrapper took 0.001999 seconds
# 2023-10-06 10:33:23,492 - TPE using 44/44 trials with best loss 164.437247
#  90%|█████████ | 45/50 [00:17<00:01,  2.51trial/s, best loss: 164.43724697712824]2023-10-06 10:33:23,795 - build_posterior_wrapper took 0.001999 seconds
# 2023-10-06 10:33:23,796 - TPE using 45/45 trials with best loss 164.437247
# 2023-10-06 10:33:23,811 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 255 to 240.
#  92%|█████████▏| 46/50 [00:18<00:01,  2.06trial/s, best loss: 164.43724697712824]2023-10-06 10:33:24,483 - build_posterior_wrapper took 0.001997 seconds
# 2023-10-06 10:33:24,484 - TPE using 46/46 trials with best loss 164.437247
# 2023-10-06 10:33:24,499 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 304 to 240.
#  94%|█████████▍| 47/50 [00:19<00:01,  1.82trial/s, best loss: 164.43724697712824]2023-10-06 10:33:25,183 - build_posterior_wrapper took 0.001999 seconds
# 2023-10-06 10:33:25,184 - TPE using 47/47 trials with best loss 164.437247
# 2023-10-06 10:33:25,199 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 448 to 240.
#  96%|█████████▌| 48/50 [00:20<00:01,  1.70trial/s, best loss: 164.43724697712824]2023-10-06 10:33:25,857 - build_posterior_wrapper took 0.001997 seconds
# 2023-10-06 10:33:25,858 - TPE using 48/48 trials with best loss 164.437247
#  98%|█████████▊| 49/50 [00:20<00:00,  2.01trial/s, best loss: 164.43724697712824]2023-10-06 10:33:26,144 - build_posterior_wrapper took 0.002998 seconds
# 2023-10-06 10:33:26,145 - TPE using 49/49 trials with best loss 164.437247
# 2023-10-06 10:33:26,161 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 277 to 240.
# 100%|██████████| 50/50 [00:20<00:00,  2.14trial/s, best loss: 164.43724697712824]
# 2023-10-06 10:33:26,820 - SimultaneousTuner - Hyperparameters optimization finished
# 2023-10-06 10:33:27,073 - SimultaneousTuner - Return tuned graph due to the fact that obtained metric 164.437 equal or better than initial (+ 0.05% deviation) 241.395
# 2023-10-06 10:33:27,074 - SimultaneousTuner - Final graph: {'depth': 3, 'length': 3, 'nodes': [lasso, custom, lagged]}
# lasso - {'alpha': 1.0983510536759178}
# custom - {'alpha': 3.0896279976959677, 'model_predict': <function custom_ml_model_imitation_predict at 0x000002689F6A99D0>, 'model_fit': <function custom_ml_model_imitation_fit at 0x000002689F6A9940>}
# lagged - {'window_size': 28}
# 2023-10-06 10:33:27,075 - SimultaneousTuner - Final metric: 164.437
# Pipeline structure:
# {'depth': 3, 'length': 3, 'nodes': [lasso, custom, lagged]}
# lasso - {}
# custom - {'alpha': 5, 'model_predict': <function custom_ml_model_imitation_predict at 0x000002689F6A99D0>, 'model_fit': <function custom_ml_model_imitation_fit at 0x000002689F6A9940>}
# lagged - {'window_size': 10}

# %%
plot_results(predicted_before_tuning, predicted_values, target)

# %%
predicted_before_tuning, predicted_values, target = run_pipeline_tuning(pipeline_type='without_fit')
# Out:
# Pipeline structure:
# {'depth': 3, 'length': 3, 'nodes': [ridge, custom, lagged]}
# ridge - {}
# custom - {'a': -50, 'b': 500, 'model_predict': <function domain_model_imitation_predict at 0x000002689F6A98B0>}
# lagged - {'window_size': 10}
# 2023-10-06 10:33:27,647 - DataSourceSplitter - Hold out validation is applied.
# 2023-10-06 10:33:27,650 - SimultaneousTuner - Hyperparameters optimization start: estimation of metric for initial graph
# 2023-10-06 10:33:27,791 - SimultaneousTuner - Initial graph: {'depth': 3, 'length': 3, 'nodes': [ridge, custom, lagged]}
# ridge - {}
# custom - {'a': -50, 'b': 500, 'model_predict': <function domain_model_imitation_predict at 0x000002689F6A98B0>}
# lagged - {'window_size': 10}
# Initial metric: [38109.959]
#   0%|          | 0/5 [00:00<?, ?trial/s, best loss=?]2023-10-06 10:33:27,800 - build_posterior_wrapper took 0.002000 seconds
# 2023-10-06 10:33:27,801 - TPE using 0 trials
# 2023-10-06 10:33:27,895 - build_posterior_wrapper took 0.001999 seconds
# 2023-10-06 10:33:27,897 - TPE using 1/1 trials with best loss 30480.276760
#  40%|████      | 2/5 [00:00<00:00, 10.70trial/s, best loss: 30480.27675951761]2023-10-06 10:33:27,989 - build_posterior_wrapper took 0.002999 seconds
# 2023-10-06 10:33:27,990 - TPE using 2/2 trials with best loss 30480.276760
# 2023-10-06 10:33:28,077 - build_posterior_wrapper took 0.001999 seconds
# 2023-10-06 10:33:28,079 - TPE using 3/3 trials with best loss 30480.276760
#  80%|████████  | 4/5 [00:00<00:00, 11.05trial/s, best loss: 30480.27675951761]2023-10-06 10:33:28,165 - build_posterior_wrapper took 0.001999 seconds
# 2023-10-06 10:33:28,166 - TPE using 4/4 trials with best loss 30480.276760
# 100%|██████████| 5/5 [00:00<00:00, 11.05trial/s, best loss: 30480.27675951761]
#  10%|█         | 5/50 [00:00<?, ?trial/s, best loss=?]2023-10-06 10:33:28,258 - build_posterior_wrapper took 0.002001 seconds
# 2023-10-06 10:33:28,260 - TPE using 5/5 trials with best loss 30480.276760
# 2023-10-06 10:33:28,264 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 272 to 240.
#  12%|█▏        | 6/50 [00:00<00:28,  1.53trial/s, best loss: 636.4213823493861]2023-10-06 10:33:28,914 - build_posterior_wrapper took 0.001998 seconds
# 2023-10-06 10:33:28,915 - TPE using 6/6 trials with best loss 636.421382
#  14%|█▍        | 7/50 [00:00<00:18,  2.29trial/s, best loss: 636.4213823493861]2023-10-06 10:33:29,197 - build_posterior_wrapper took 0.002998 seconds
# 2023-10-06 10:33:29,197 - TPE using 7/7 trials with best loss 636.421382
# 2023-10-06 10:33:29,202 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 391 to 240.
#  16%|█▌        | 8/50 [00:01<00:22,  1.90trial/s, best loss: 636.4213823493861]2023-10-06 10:33:29,832 - build_posterior_wrapper took 0.001997 seconds
# 2023-10-06 10:33:29,833 - TPE using 8/8 trials with best loss 636.421382
# 2023-10-06 10:33:29,837 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 446 to 240.
#  18%|█▊        | 9/50 [00:02<00:24,  1.69trial/s, best loss: 636.4213823493861]2023-10-06 10:33:30,521 - build_posterior_wrapper took 0.001999 seconds
# 2023-10-06 10:33:30,523 - TPE using 9/9 trials with best loss 636.421382
#  20%|██        | 10/50 [00:02<00:21,  1.83trial/s, best loss: 636.4213823493861]2023-10-06 10:33:30,989 - build_posterior_wrapper took 0.001997 seconds
# 2023-10-06 10:33:30,991 - TPE using 10/10 trials with best loss 636.421382
# 2023-10-06 10:33:31,073 - build_posterior_wrapper took 0.002000 seconds
# 2023-10-06 10:33:31,074 - TPE using 11/11 trials with best loss 495.105701
#  24%|██▍       | 12/50 [00:03<00:16,  2.29trial/s, best loss: 495.1057010159953]2023-10-06 10:33:31,648 - build_posterior_wrapper took 0.001997 seconds
# 2023-10-06 10:33:31,649 - TPE using 12/12 trials with best loss 495.105701
# 2023-10-06 10:33:31,654 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 400 to 240.
#  26%|██▌       | 13/50 [00:04<00:18,  2.02trial/s, best loss: 495.1057010159953]2023-10-06 10:33:32,301 - build_posterior_wrapper took 0.001998 seconds
# 2023-10-06 10:33
- LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 322 to 240.
#  82%|████████▏ | 41/50 [00:17<00:04,  1.94trial/s, best loss: 495.1057010159953]2023-10-06 10:33:45,709 - build_posterior_wrapper took 0.001993 seconds
# 2023-10-06 10:33:45,710 - TPE using 41/41 trials with best loss 495.105701
#  84%|████████▍ | 42/50 [00:17<00:03,  2.41trial/s, best loss: 495.1057010159953]2023-10-06 10:33:45,893 - build_posterior_wrapper took 0.001999 seconds
# 2023-10-06 10:33:45,894 - TPE using 42/42 trials with best loss 495.105701
#  86%|████████▌ | 43/50 [00:18<00:02,  2.46trial/s, best loss: 495.1057010159953]2023-10-06 10:33:46,278 - build_posterior_wrapper took 0.001998 seconds
# 2023-10-06 10:33:46,280 - TPE using 43/43 trials with best loss 495.105701
#  88%|████████▊ | 44/50 [00:18<00:02,  2.11trial/s, best loss: 495.1057010159953]2023-10-06 10:33:46,912 - build_posterior_wrapper took 0.002001 seconds
# 2023-10-06 10:33:46,913 - TPE using 44/44 trials with best loss 495.105701
# 2023-10-06 10:33:46,931 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 321 to 240.
#  90%|█████████ | 45/50 [00:19<00:02,  1.90trial/s, best loss: 495.1057010159953]2023-10-06 10:33:47,561 - build_posterior_wrapper took 0.001999 seconds
# 2023-10-06 10:33:47,563 - TPE using 45/45 trials with best loss 495.105701
#  92%|█████████▏| 46/50 [00:19<00:02,  1.83trial/s, best loss: 495.1057010159953]2023-10-06 10:33:48,156 - build_posterior_wrapper took 0.001999 seconds
# 2023-10-06 10:33:48,157 - TPE using 46/46 trials with best loss 495.105701
#  94%|█████████▍| 47/50 [00:20<00:01,  2.09trial/s, best loss: 495.1057010159953]2023-10-06 10:33:48,472 - build_posterior_wrapper took 0.002999 seconds
# 2023-10-06 10:33:48,473 - TPE using 47/47 trials with best loss 495.105701
# 2023-10-06 10:33:48,493 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 466 to 240.
#  96%|█████████▌| 48/50 [00:20<00:01,  1.80trial/s, best loss: 495.1057010159953]2023-10-06 10:33:49,208 - build_posterior_wrapper took 0.001998 seconds
# 2023-10-06 10:33:49,209 - TPE using 48/48 trials with best loss 495.105701
# 2023-10-06 10:33:49,227 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 266 to 240.
#  98%|█████████▊| 49/50 [00:21<00:00,  1.69trial/s, best loss: 495.1057010159953]2023-10-06 10:33:49,886 - build_posterior_wrapper took 0.001998 seconds
# 2023-10-06 10:33:49,888 - TPE using 49/49 trials with best loss 495.105701
# 100%|██████████| 50/50 [00:21<00:00,  2.07trial/s, best loss: 495.1057010159953]
# 2023-10-06 10:33:50,023 - SimultaneousTuner - Hyperparameters optimization finished
# 2023-10-06 10:33:50,126 - SimultaneousTuner - Return tuned graph due to the fact that obtained metric 435.521 equal or better than initial (+ 0.05% deviation) 38090.904
# 2023-10-06 10:33:50,127 - SimultaneousTuner - Final graph: {'depth': 3, 'length': 3, 'nodes': [ridge, custom, lagged]}
# ridge - {'alpha': 9.577672895830268}
# custom - {'a': -16.934975692231106, 'b': 88.21902072400734, 'model_predict': <function domain_model_imitation_predict at 0x000002689F6A98B0>}
# lagged - {'window_size': 9}
# 2023-10-06 10:33:50,128 - SimultaneousTuner - Final metric: 435.521
# Pipeline structure:
# {'depth': 3, 'length': 3, 'nodes': [ridge, custom, lagged]}
# ridge - {}
# custom - {'a': -50, 'b': 500, 'model_predict': <function domain_model_imitation_predict at 0x000002689F6A98B0>}
# lagged - {'window_size': 10}

# %%
plot_results(predicted_before_tuning, predicted_values, target)

# %% [markdown]
# Thus, we demonstrated the use of imitation of custom model with FEDOT for providing the hybrid approach in composition with AutoML.
