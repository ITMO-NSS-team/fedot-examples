# %% [markdown]
# ## Using FEDOT for hybrid modeling with custom model tuning

# %% [markdown]
# #### FEDOT version = 0.6.1

# %%
# !pip install fedot==0.6.1
# Out:
# Requirement already satisfied: fedot==0.6.1 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (0.6.1)
# Requirement already satisfied: tqdm in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from fedot==0.6.1) (4.64.0)
# Requirement already satisfied: hyperopt==0.2.7 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from fedot==0.6.1) (0.2.7)
# Requirement already satisfied: anytree>=2.8.* in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from fedot==0.6.1) (2.8.0)
# Requirement already satisfied: pytest>=6.2.* in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from fedot==0.6.1) (7.1.2)
# Requirement already satisfied: SALib>=1.3.* in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from fedot==0.6.1) (1.4.6b1)
# Requirement already satisfied: func-timeout==4.3.5 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from fedot==0.6.1) (4.3.5)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from fedot==0.6.1) (3.3.2)
# Requirement already satisfied: statsmodels>=0.12.0 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from fedot==0.6.1) (0.13.2)
# Requirement already satisfied: pyvis==0.2.1 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from fedot==0.6.1) (0.2.1)
# Requirement already satisfied: psutil>=5.9.2 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from fedot==0.6.1) (5.9.2)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from fedot==0.6.1) (1.4.3)
# Requirement already satisfied: numpy>=1.16.* in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from fedot==0.6.1) (1.23.2)
# Requirement already satisfied: scikit-learn in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from fedot==0.6.1) (1.1.2)
# Requirement already satisfied: catboost>=0.25.* in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from fedot==0.6.1) (1.0.6)
# Requirement already satisfied: testfixtures>=6.18.* in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from fedot==0.6.1) (7.0.0)
# Requirement already satisfied: joblib>=0.17.* in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from fedot==0.6.1) (1.1.0)
# Requirement already satisfied: requests>=2.* in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from fedot==0.6.1) (2.28.1)
# Requirement already satisfied: ete3>=3.1.* in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from fedot==0.6.1) (3.1.2)
# Requirement already satisfied: xgboost>=1.6.0 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from fedot==0.6.1) (1.6.2)
# Requirement already satisfied: scikit-optimize>=0.7.4 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from fedot==0.6.1) (0.9.0)
# Requirement already satisfied: matplotlib>=3.3.1 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from fedot==0.6.1) (3.5.3)
# Requirement already satisfied: typing>=3.7.* in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from fedot==0.6.1) (3.7.4.3)
# Requirement already satisfied: seaborn>=0.9.* in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from fedot==0.6.1) (0.12.0rc0)
# Requirement already satisfied: networkx!=2.7.*,!=2.8.1,!=2.8.2,!=2.8.3,>=2.4 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from fedot==0.6.1) (2.8.6)
# Requirement already satisfied: future in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from hyperopt==0.2.7->fedot==0.6.1) (0.18.2)
# Requirement already satisfied: six in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from hyperopt==0.2.7->fedot==0.6.1) (1.16.0)
# Requirement already satisfied: py4j in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from hyperopt==0.2.7->fedot==0.6.1) (0.10.9.7)
# Requirement already satisfied: scipy in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from hyperopt==0.2.7->fedot==0.6.1) (1.9.1)
# Requirement already satisfied: cloudpickle in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from hyperopt==0.2.7->fedot==0.6.1) (2.1.0)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from pyvis==0.2.1->fedot==0.6.1) (8.4.0)
# Requirement already satisfied: jinja2>=2.9.6 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from pyvis==0.2.1->fedot==0.6.1) (3.1.2)
# Requirement already satisfied: jsonpickle>=1.4.1 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from pyvis==0.2.1->fedot==0.6.1) (2.2.0)
# Requirement already satisfied: graphviz in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from catboost>=0.25.*->fedot==0.6.1) (0.20)
# Requirement already satisfied: plotly in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from catboost>=0.25.*->fedot==0.6.1) (5.10.0)
# Requirement already satisfied: wheel in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from lightgbm>=3.0.0->fedot==0.6.1) (0.37.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=3.3.1->fedot==0.6.1) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=3.3.1->fedot==0.6.1) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=3.3.1->fedot==0.6.1) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=3.3.1->fedot==0.6.1) (4.37.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=3.3.1->fedot==0.6.1) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=3.3.1->fedot==0.6.1) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=3.3.1->fedot==0.6.1) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from pandas>=1.3.0->fedot==0.6.1) (2022.2.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from pytest>=6.2.*->fedot==0.6.1) (1.0.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from pytest>=6.2.*->fedot==0.6.1) (22.1.0)
# Requirement already satisfied: py>=1.8.2 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from pytest>=6.2.*->fedot==0.6.1) (1.11.0)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from pytest>=6.2.*->fedot==0.6.1) (2.0.1)
# Requirement already satisfied: colorama in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from pytest>=6.2.*->fedot==0.6.1) (0.4.5)
# Requirement already satisfied: atomicwrites>=1.0 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from pytest>=6.2.*->fedot==0.6.1) (1.4.1)
# Requirement already satisfied: iniconfig in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from pytest>=6.2.*->fedot==0.6.1) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from requests>=2.*->fedot==0.6.1) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from requests>=2.*->fedot==0.6.1) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from requests>=2.*->fedot==0.6.1) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from requests>=2.*->fedot==0.6.1) (1.26.12)
# Requirement already satisfied: setuptools in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from SALib>=1.3.*->fedot==0.6.1) (65.3.0)
# Requirement already satisfied: pathos in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from SALib>=1.3.*->fedot==0.6.1) (0.2.9)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn->fedot==0.6.1) (3.1.0)
# Requirement already satisfied: pyaml>=16.9 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from scikit-optimize>=0.7.4->fedot==0.6.1) (21.10.1)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from statsmodels>=0.12.0->fedot==0.6.1) (0.5.2)
# Requirement already satisfied: backcall in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from ipython>=5.3.0->pyvis==0.2.1->fedot==0.6.1) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from ipython>=5.3.0->pyvis==0.2.1->fedot==0.6.1) (3.0.30)
# Requirement already satisfied: stack-data in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from ipython>=5.3.0->pyvis==0.2.1->fedot==0.6.1) (0.4.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from ipython>=5.3.0->pyvis==0.2.1->fedot==0.6.1) (2.13.0)
# Requirement already satisfied: traitlets>=5 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from ipython>=5.3.0->pyvis==0.2.1->fedot==0.6.1) (5.3.0)
# Requirement already satisfied: decorator in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from ipython>=5.3.0->pyvis==0.2.1->fedot==0.6.1) (5.1.1)
# Requirement already satisfied: matplotlib-inline in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from ipython>=5.3.0->pyvis==0.2.1->fedot==0.6.1) (0.1.6)
# Requirement already satisfied: jedi>=0.16 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from ipython>=5.3.0->pyvis==0.2.1->fedot==0.6.1) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from ipython>=5.3.0->pyvis==0.2.1->fedot==0.6.1) (0.7.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from jinja2>=2.9.6->pyvis==0.2.1->fedot==0.6.1) (2.1.1)
# Requirement already satisfied: PyYAML in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from pyaml>=16.9->scikit-optimize>=0.7.4->fedot==0.6.1) (6.0)
# Requirement already satisfied: pox>=0.3.1 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from pathos->SALib>=1.3.*->fedot==0.6.1) (0.3.1)
# Requirement already satisfied: dill>=0.3.5.1 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from pathos->SALib>=1.3.*->fedot==0.6.1) (0.3.5.1)
# Requirement already satisfied: multiprocess>=0.70.13 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from pathos->SALib>=1.3.*->fedot==0.6.1) (0.70.13)
# Requirement already satisfied: ppft>=1.7.6.5 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from pathos->SALib>=1.3.*->fedot==0.6.1) (1.7.6.5)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from plotly->catboost>=0.25.*->fedot==0.6.1) (8.0.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis==0.2.1->fedot==0.6.1) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->pyvis==0.2.1->fedot==0.6.1) (0.2.5)
# Requirement already satisfied: pure-eval in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis==0.2.1->fedot==0.6.1) (0.2.2)
# Requirement already satisfied: executing in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis==0.2.1->fedot==0.6.1) (0.10.0)
# Requirement already satisfied: asttokens in c:\users\valery\appdata\local\programs\python\python38\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis==0.2.1->fedot==0.6.1) (2.0.8)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m !pip install --upgrade pip

# %% [markdown]
# [Original repository on GitHub](https://github.com/nccr-itmo/FEDOT)
#
# This tutorial was prepared by [Natural Systems Simulation Team](https://github.com/ITMO-NSS-team)
#
# ---
#
# If you want to learn some basic things about FEDOT and time series forecasting, you can use [this notebook](3_intro_ts_forecasting.ipynb).

# %%
# Additional imports 
import numpy as np
import pandas as pd
from hyperopt import hp
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error

# Imports for creating plots
import matplotlib.pyplot as plt
from pylab import rcParams
rcParams['figure.figsize'] = 18, 7

# Pipeline and nodes
from fedot.core.pipelines.node import PrimaryNode, SecondaryNode
from fedot.core.pipelines.pipeline import Pipeline

# Data
from fedot.core.repository.dataset_types import DataTypesEnum
from fedot.core.data.data import InputData
from fedot.core.data.data_split import train_test_data_setup

# Tasks
from fedot.core.repository.tasks import TaskTypesEnum, Task, TsForecastingParams

#Tuning
from fedot.core.pipelines.tuning.search_space import SearchSpace
from fedot.core.pipelines.tuning.unified import PipelineTuner

import warnings
warnings.filterwarnings('ignore')

import logging
logging.raiseExceptions = False

# %%
# Read the file
df = pd.read_csv('../data/metocean.csv')

plt.plot(np.arange(len(df['value'])), df['value'])
plt.grid()
plt.show()

# Specify forecast length
len_forecast = 50

# Got univariate time series as numpy array
time_series = np.array(df['value'])

# Wrapp data into InputData
task = Task(TaskTypesEnum.ts_forecasting, TsForecastingParams(forecast_length=len_forecast))

# Split data into train and test
train_input, predict_input = train_test_data_setup(InputData(idx=range(len(time_series)),
                                                                 features=time_series,
                                                                 target=time_series,
                                                                 task=Task(TaskTypesEnum.ts_forecasting,
                                                                           TsForecastingParams(forecast_length=len_forecast)),
                                                                 data_type=DataTypesEnum.ts))

# %% [markdown]
# We have a time series of sea level. Based on this time series we will conduct the case of forecasting with custom model implantation in the pipeline.

# %% [markdown]
# ### Custom model specification

# %% [markdown]
# Some custom models have necessary step of fitting, but some of them such as domain specific models doesn't need fitting at all. For using with FEDOT custom model should be wrapped into function that provides fit (if it is necessary) and predict steps. Fit step returns model object, predict step returns predicted values.

# %%
# Let's prepare a function for imitation custom model without fitting
def domain_model_imitation_predict(fitted_model: any, idx: np.array, predict_data: np.array, params: dict):
    a = params.get('a')
    b = params.get('b')
    shape = predict_data.shape
    result = np.random.rand(*shape) * a + b
    # Available output_type's 'table', 'ts', 'image', 'text'
    return result, 'table'

# Function for custom regression model imitation (fit)
def custom_ml_model_imitation_fit(idx: np.array, features: np.array, target: np.array, params: dict):
    alpha = params.get('alpha')
    reg = Ridge(alpha=alpha)
    reg.fit(features, target)
    return reg

# Function for custom regression model imitation (predict)
def custom_ml_model_imitation_predict(fitted_model: any, idx: np.array, features: np.array, params: dict):
    res = fitted_model.predict(features)
    return res, 'table'

# %% [markdown]
# Including custom model into pipeline is provided by using custom parameters of node. Also there should be indicated parameters of model for tune and initial approximation for them.

# %%
# Let's prepare a function for pipeline with custom node without fitting
def get_domain_pipeline():
    """
        Pipeline looking like this
        lagged -> custom -> ridge
    """
    lagged_node = PrimaryNode('lagged')
    lagged_node.parameters = {'window_size': 10}

    # For custom model params as initial approximation and model as function is necessary
    custom_node = SecondaryNode('custom', nodes_from=[lagged_node])
    custom_node.parameters = {"a": -50, "b": 500, 'model_predict': domain_model_imitation_predict}

    node_final = SecondaryNode('ridge', nodes_from=[custom_node])
    pipeline = Pipeline(node_final)

    return pipeline

# Function for pipeline with custom node with fitting
def get_fitting_custom_pipeline():
    """
        Pipeline looking like this
        lagged -> custom -> ridge
    """
    lagged_node = PrimaryNode('lagged')
    lagged_node.parameters = {'window_size': 10}

    # For custom model params as initial approximation and model as function is necessary
    custom_node = SecondaryNode('custom', nodes_from=[lagged_node])
    custom_node.parameters = {'alpha': 5,
                                 'model_predict': custom_ml_model_imitation_predict,
                                 'model_fit': custom_ml_model_imitation_fit}

    node_final = SecondaryNode('lasso', nodes_from=[custom_node])
    pipeline = Pipeline(node_final)

    return pipeline

# %% [markdown]
# For pipeline tuning search space of custom model parameters should be specified. Hyperopt wrapper is used for that.

# %% [markdown]
# ### Function for prediction with/without fitting custom model

# %%
from fedot.core.pipelines.tuning.tuner_builder import TunerBuilder
from fedot.core.pipelines.tuning.unified import PipelineTuner
from fedot.core.repository.quality_metrics_repository import \
    MetricsRepository, RegressionMetricsEnum


def run_pipeline_tuning(pipeline_type):

    if pipeline_type == 'with_fit':
        pipeline = get_fitting_custom_pipeline()
        # Setting custom search space for tuner (necessary)
        # model and output_type should be wrapped into hyperopt
        custom_search_space = {'custom': {
            'alpha': (hp.uniform, [0.01, 10]),
            'model_predict': (hp.choice, [[custom_ml_model_imitation_predict]]),
            'model_fit': (hp.choice, [[custom_ml_model_imitation_fit]])}}
    elif pipeline_type == 'without_fit':
        pipeline = get_domain_pipeline()
        # Setting custom search space for tuner (necessary)
        # model and output_type should be wrapped into hyperopt
        custom_search_space = {'custom': {'a': (hp.uniform, [-100, 100]),
                                          'b': (hp.uniform, [0, 1000]),
                                          'model_predict': (hp.choice, [[domain_model_imitation_predict]])}}
    pipeline.fit_from_scratch(train_input)
    pipeline.print_structure()
    # Get prediction with initial approximation
    predicted_before_tuning = pipeline.predict(predict_input).predict

    replace_default_search_space = True

    # Start tuning all nodes in the pipeline 
    tuner = TunerBuilder(train_input.task)\
            .with_tuner(PipelineTuner)\
            .with_metric(RegressionMetricsEnum.MSE)\
            .with_iterations(50) \
            .with_cv_folds(None) \
            .with_validation_blocks(3) \
            .with_search_space(SearchSpace(custom_search_space=custom_search_space,
                                                                replace_default_search_space=replace_default_search_space))\
            .build(train_input)
    tuned_pipeline = tuner.tune(pipeline)
    
    # Fit pipeline on the entire train data
    pipeline.fit(train_input)
    # Predict tuned pipeline
    predicted_values = pipeline.predict(predict_input).predict
    pipeline.print_structure()

    plt.plot(np.arange(len(predicted_before_tuning[0])), predicted_before_tuning[0], label='Before tuning')
    plt.plot(np.arange(len(predicted_values[0])), predicted_values[0], label='After tuning')
    plt.plot(np.arange(len(predict_input.target)), predict_input.target, label='Real')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ### Case with using model with fitting

# %%
run_pipeline_tuning(pipeline_type='with_fit')
# Out:
# Pipeline structure:
# {'depth': 3, 'length': 3, 'nodes': [lasso, custom, lagged]}
# lasso - {}
# custom - {'alpha': 5, 'model_predict': <function custom_ml_model_imitation_predict at 0x0000021C4C45C670>, 'model_fit': <function custom_ml_model_imitation_fit at 0x0000021C4C45C5E0>}
# lagged - {'window_size': 10}
# 2022-12-17 17:00:10,235 - DataSourceSplitter - Hold out validation is applied.
# 2022-12-17 17:00:10,236 - PipelineTuner - Hyperparameters optimization start
# 2022-12-17 17:00:10,372 - PipelineTuner - Initial pipeline: {'depth': 3, 'length': 3, 'nodes': [lasso, custom, lagged]}
# lasso - {}
# custom - {'alpha': 5, 'model_predict': <function custom_ml_model_imitation_predict at 0x0000021C4C45C670>, 'model_fit': <function custom_ml_model_imitation_fit at 0x0000021C4C45C5E0>}
# lagged - {'window_size': 10}
# Initial metric: 241.516
#   0%|                                                                            | 0/5 [00:00<?, ?trial/s, best loss=?]2022-12-17 17:00:10,377 - build_posterior_wrapper took 0.001000 seconds
# 2022-12-17 17:00:10,379 - TPE using 0 trials
#  20%|██████████                                        | 1/5 [00:00<00:00,  9.22trial/s, best loss: 242.15145868585537]2022-12-17 17:00:10,486 - build_posterior_wrapper took 0.000988 seconds
# 2022-12-17 17:00:10,487 - TPE using 1/1 trials with best loss 242.151459
# 2022-12-17 17:00:10,569 - build_posterior_wrapper took 0.002001 seconds
# 2022-12-17 17:00:10,569 - TPE using 2/2 trials with best loss 242.151459
#  60%|██████████████████████████████                    | 3/5 [00:00<00:00, 10.21trial/s, best loss: 242.15145868585537]2022-12-17 17:00:10,676 - build_posterior_wrapper took 0.001999 seconds
# 2022-12-17 17:00:10,677 - TPE using 3/3 trials with best loss 242.151459
# 2022-12-17 17:00:10,756 - build_posterior_wrapper took 0.001000 seconds
# 2022-12-17 17:00:10,757 - TPE using 4/4 trials with best loss 242.151459
# 100%|██████████████████████████████████████████████████| 5/5 [00:00<00:00, 10.73trial/s, best loss: 242.15145868585537]
#  10%|███████▌                                                                   | 5/50 [00:00<?, ?trial/s, best loss=?]2022-12-17 17:00:10,847 - build_posterior_wrapper took 0.001000 seconds
# 2022-12-17 17:00:10,848 - TPE using 5/5 trials with best loss 242.151459
# 2022-12-17 17:00:10,851 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 273 to 240.
#  12%|█████▉                                           | 6/50 [00:00<00:13,  3.26trial/s, best loss: 242.15145868585537]2022-12-17 17:00:11,154 - build_posterior_wrapper took 0.001007 seconds
# 2022-12-17 17:00:11,156 - TPE using 6/6 trials with best loss 242.151459
# 2022-12-17 17:00:11,159 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 345 to 240.
#  14%|██████▊                                          | 7/50 [00:00<00:15,  2.79trial/s, best loss: 242.15145868585537]2022-12-17 17:00:11,549 - build_posterior_wrapper took 0.002000 seconds
# 2022-12-17 17:00:11,550 - TPE using 7/7 trials with best loss 242.151459
# 2022-12-17 17:00:11,634 - build_posterior_wrapper took 0.001002 seconds
# 2022-12-17 17:00:11,636 - TPE using 8/8 trials with best loss 242.151459
# 2022-12-17 17:00:11,639 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 385 to 240.
#  18%|████████▊                                        | 9/50 [00:01<00:10,  3.80trial/s, best loss: 242.15145868585537]2022-12-17 17:00:11,962 - build_posterior_wrapper took 0.001001 seconds
# 2022-12-17 17:00:11,963 - TPE using 9/9 trials with best loss 242.151459
#  20%|█████████▌                                      | 10/50 [00:01<00:10,  3.84trial/s, best loss: 242.15145868585537]2022-12-17 17:00:12,217 - build_posterior_wrapper took 0.001001 seconds
# 2022-12-17 17:00:12,218 - TPE using 10/10 trials with best loss 242.151459
#  22%|██████████▌                                     | 11/50 [00:01<00:09,  4.32trial/s, best loss: 242.15145868585537]2022-12-17 17:00:12,384 - build_posterior_wrapper took 0.002002 seconds
# 2022-12-17 17:00:12,385 - TPE using 11/11 trials with best loss 242.151459
# 2022-12-17 17:00:12,460 - build_posterior_wrapper took 0.001000 seconds
# 2022-12-17 17:00:12,461 - TPE using 12/12 trials with best loss 242.151459
# 2022-12-17 17:00:12,464 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 481 to 240.
#  26%|████████████▍                                   | 13/50 [00:01<00:07,  4.66trial/s, best loss: 242.15145868585537]2022-12-17 17:00:12,772 - build_posterior_wrapper took 0.001001 seconds
# 2022-12-17 17:00:12,774 - TPE using 13/13 trials with best loss 242.151459
#  28%|█████████████▍                                  | 14/50 [00:02<00:07,  4.86trial/s, best loss: 242.15145868585537]2022-12-17 17:00:12,952 - build_posterior_wrapper took 0.002005 seconds
# 2022-12-17 17:00:12,953 - TPE using 14/14 trials with best loss 242.151459
#  30%|██████████████▍                                 | 15/50 [00:02<00:07,  4.51trial/s, best loss: 242.15145868585537]2022-12-17 17:00:13,218 - build_posterior_wrapper took 0.001001 seconds
# 2022-12-17 17:00:13,219 - TPE using 15/15 trials with best loss 242.151459
# 2022-12-17 17:00:13,223 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 409 to 240.
#  32%|███████████████▎                                | 16/50 [00:02<00:08,  4.14trial/s, best loss: 242.15145868585537]2022-12-17 17:00:13,513 - build_posterior_wrapper took 0.001000 seconds
# 2022-12-17 17:00:13,514 - TPE using 16/16 trials with best loss 242.151459
# 2022-12-17 17:00:13,517 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 271 to 240.
#  34%|████████████████▎                               | 17/50 [00:02<00:08,  3.86trial/s, best loss: 242.15145868585537]2022-12-17 17:00:13,817 - build_posterior_wrapper took 0.000978 seconds
# 2022-12-17 17:00:13,818 - TPE using 17/17 trials with best loss 242.151459
#  36%|█████████████████▎                              | 18/50 [00:03<00:06,  4.66trial/s, best loss: 242.15145868585537]2022-12-17 17:00:13,922 - build_posterior_wrapper took 0.002007 seconds
# 2022-12-17 17:00:13,923 - TPE using 18/18 trials with best loss 242.151459
# 2022-12-17 17:00:13,926 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 297 to 240.
#  38%|██████████████████▏                             | 19/50 [00:03<00:07,  4.14trial/s, best loss: 242.15145868585537]2022-12-17 17:00:14,227 - build_posterior_wrapper took 0.001000 seconds
# 2022-12-17 17:00:14,229 - TPE using 19/19 trials with best loss 242.151459
# 2022-12-17 17:00:14,232 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from
- LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 253 to 240.
#  82%|███████████████████████████████████████▎        | 41/50 [00:09<00:02,  4.16trial/s, best loss: 174.11486403209895]2022-12-17 17:00:20,324 - build_posterior_wrapper took 0.002010 seconds
# 2022-12-17 17:00:20,325 - TPE using 41/41 trials with best loss 174.114864
#  84%|████████████████████████████████████████▎       | 42/50 [00:09<00:01,  4.55trial/s, best loss: 174.11486403209895]2022-12-17 17:00:20,485 - build_posterior_wrapper took 0.001005 seconds
# 2022-12-17 17:00:20,486 - TPE using 42/42 trials with best loss 174.114864
#  86%|█████████████████████████████████████████▎      | 43/50 [00:09<00:01,  3.97trial/s, best loss: 174.11486403209895]2022-12-17 17:00:20,824 - build_posterior_wrapper took 0.000987 seconds
# 2022-12-17 17:00:20,825 - TPE using 43/43 trials with best loss 174.114864
# 2022-12-17 17:00:20,834 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 298 to 240.
#  88%|██████████████████████████████████████████▏     | 44/50 [00:10<00:01,  3.58trial/s, best loss: 174.11486403209895]2022-12-17 17:00:21,171 - build_posterior_wrapper took 0.001013 seconds
# 2022-12-17 17:00:21,172 - TPE using 44/44 trials with best loss 174.114864
# 2022-12-17 17:00:21,182 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 499 to 240.
#  90%|███████████████████████████████████████████▏    | 45/50 [00:10<00:01,  3.48trial/s, best loss: 174.11486403209895]2022-12-17 17:00:21,479 - build_posterior_wrapper took 0.000992 seconds
# 2022-12-17 17:00:21,481 - TPE using 45/45 trials with best loss 174.114864
# 2022-12-17 17:00:21,489 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 406 to 240.
#  92%|████████████████████████████████████████████▏   | 46/50 [00:10<00:01,  3.43trial/s, best loss: 174.11486403209895]2022-12-17 17:00:21,782 - build_posterior_wrapper took 0.001000 seconds
# 2022-12-17 17:00:21,783 - TPE using 46/46 trials with best loss 174.114864
#  94%|█████████████████████████████████████████████   | 47/50 [00:11<00:00,  3.82trial/s, best loss: 174.11486403209895]2022-12-17 17:00:21,972 - build_posterior_wrapper took 0.001006 seconds
# 2022-12-17 17:00:21,973 - TPE using 47/47 trials with best loss 174.114864
#  96%|██████████████████████████████████████████████  | 48/50 [00:11<00:00,  4.64trial/s, best loss: 174.11486403209895]2022-12-17 17:00:22,077 - build_posterior_wrapper took 0.001963 seconds
# 2022-12-17 17:00:22,078 - TPE using 48/48 trials with best loss 174.114864
#  98%|███████████████████████████████████████████████ | 49/50 [00:11<00:00,  4.19trial/s, best loss: 174.11486403209895]2022-12-17 17:00:22,370 - build_posterior_wrapper took 0.000994 seconds
# 2022-12-17 17:00:22,371 - TPE using 49/49 trials with best loss 174.114864
# 2022-12-17 17:00:22,380 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 347 to 240.
# 100%|████████████████████████████████████████████████| 50/50 [00:11<00:00,  3.80trial/s, best loss: 174.11486403209895]
# 2022-12-17 17:00:22,977 - PipelineTuner - Hyperparameters optimization finished
# 2022-12-17 17:00:22,977 - PipelineTuner - Return tuned pipeline due to the fact that obtained metric 174.115 equal or better than initial (+ 5% deviation) 253.592
# 2022-12-17 17:00:22,978 - PipelineTuner - Final pipeline: {'depth': 3, 'length': 3, 'nodes': [lasso, custom, lagged]}
# lasso - {'alpha': 0.08769736331202482}
# custom - {'alpha': 5.023277746059172, 'model_fit': <function custom_ml_model_imitation_fit at 0x0000021C4C45C5E0>, 'model_predict': <function custom_ml_model_imitation_predict at 0x0000021C4C45C670>}
# lagged - {'window_size': 32}
# 2022-12-17 17:00:22,979 - PipelineTuner - Final metric: 174.115
# Pipeline structure:
# {'depth': 3, 'length': 3, 'nodes': [lasso, custom, lagged]}
# lasso - {'alpha': 0.08769736331202482}
# custom - {'alpha': 5.023277746059172, 'model_fit': <function custom_ml_model_imitation_fit at 0x0000021C4C45C5E0>, 'model_predict': <function custom_ml_model_imitation_predict at 0x0000021C4C45C670>}
# lagged - {'window_size': 32}

# %%
run_pipeline_tuning(pipeline_type='without_fit')
# Out:
# Pipeline structure:
# {'depth': 3, 'length': 3, 'nodes': [ridge, custom, lagged]}
# ridge - {}
# custom - {'a': -50, 'b': 500, 'model_predict': <function domain_model_imitation_predict at 0x0000021C4C45C430>}
# lagged - {'window_size': 10}
# 2022-12-17 17:00:23,569 - DataSourceSplitter - Hold out validation is applied.
# 2022-12-17 17:00:23,571 - PipelineTuner - Hyperparameters optimization start
# 2022-12-17 17:00:23,614 - PipelineTuner - Initial pipeline: {'depth': 3, 'length': 3, 'nodes': [ridge, custom, lagged]}
# ridge - {}
# custom - {'a': -50, 'b': 500, 'model_predict': <function domain_model_imitation_predict at 0x0000021C4C45C430>}
# lagged - {'window_size': 10}
# Initial metric: 35055.400
#   0%|                                                                            | 0/5 [00:00<?, ?trial/s, best loss=?]2022-12-17 17:00:23,619 - build_posterior_wrapper took 0.000999 seconds
# 2022-12-17 17:00:23,620 - TPE using 0 trials
# 2022-12-17 17:00:23,662 - build_posterior_wrapper took 0.001002 seconds
# 2022-12-17 17:00:23,663 - TPE using 1/1 trials with best loss 37631.774822
# 2022-12-17 17:00:23,706 - build_posterior_wrapper took 0.001000 seconds
# 2022-12-17 17:00:23,707 - TPE using 2/2 trials with best loss 37499.103974
#  60%|██████████████████████████████▌                    | 3/5 [00:00<00:00, 22.98trial/s, best loss: 36043.81067111371]2022-12-17 17:00:23,753 - build_posterior_wrapper took 0.002996 seconds
# 2022-12-17 17:00:23,754 - TPE using 3/3 trials with best loss 36043.810671
# 2022-12-17 17:00:23,796 - build_posterior_wrapper took 0.001001 seconds
# 2022-12-17 17:00:23,797 - TPE using 4/4 trials with best loss 36043.810671
# 100%|███████████████████████████████████████████████████| 5/5 [00:00<00:00, 22.67trial/s, best loss: 35828.85936522956]
#  10%|███████▌                                                                   | 5/50 [00:00<?, ?trial/s, best loss=?]2022-12-17 17:00:23,845 - build_posterior_wrapper took 0.002010 seconds
# 2022-12-17 17:00:23,846 - TPE using 5/5 trials with best loss 35828.859365
# 2022-12-17 17:00:23,894 - build_posterior_wrapper took 0.001000 seconds
# 2022-12-17 17:00:23,895 - TPE using 6/6 trials with best loss 35828.859365
#  14%|███████                                           | 7/50 [00:00<00:06,  6.38trial/s, best loss: 6222.778591881247]2022-12-17 17:00:24,158 - build_posterior_wrapper took 0.000999 seconds
# 2022-12-17 17:00:24,159 - TPE using 7/7 trials with best loss 6222.778592
# 2022-12-17 17:00:24,162 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 276 to 240.
#  16%|████████                                          | 8/50 [00:00<00:09,  4.60trial/s, best loss: 3461.366547277095]2022-12-17 17:00:24,461 - build_posterior_wrapper took 0.001000 seconds
# 2022-12-17 17:00:24,462 - TPE using 8/8 trials with best loss 3461.366547
# 2022-12-17 17:00:24,465 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from
- LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 489 to 240.
#  86%|██████████████████████████████████████████▏      | 43/50 [00:09<00:02,  3.23trial/s, best loss: 544.3629987700928]2022-12-17 17:00:33,416 - build_posterior_wrapper took 0.001001 seconds
# 2022-12-17 17:00:33,418 - TPE using 43/43 trials with best loss 544.362999
#  88%|███████████████████████████████████████████      | 44/50 [00:09<00:01,  3.26trial/s, best loss: 544.3629987700928]2022-12-17 17:00:33,714 - build_posterior_wrapper took 0.001000 seconds
# 2022-12-17 17:00:33,715 - TPE using 44/44 trials with best loss 544.362999
# 2022-12-17 17:00:33,724 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 269 to 240.
#  90%|████████████████████████████████████████████     | 45/50 [00:10<00:01,  3.30trial/s, best loss: 544.3629987700928]2022-12-17 17:00:34,010 - build_posterior_wrapper took 0.000999 seconds
# 2022-12-17 17:00:34,011 - TPE using 45/45 trials with best loss 544.362999
#  92%|█████████████████████████████████████████████    | 46/50 [00:10<00:01,  3.91trial/s, best loss: 544.3629987700928]2022-12-17 17:00:34,155 - build_posterior_wrapper took 0.001001 seconds
# 2022-12-17 17:00:34,156 - TPE using 46/46 trials with best loss 544.362999
#  94%|██████████████████████████████████████████████   | 47/50 [00:10<00:00,  4.72trial/s, best loss: 544.3629987700928]2022-12-17 17:00:34,265 - build_posterior_wrapper took 0.001996 seconds
# 2022-12-17 17:00:34,266 - TPE using 47/47 trials with best loss 544.362999
# 2022-12-17 17:00:34,275 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 438 to 240.
#  96%|███████████████████████████████████████████████  | 48/50 [00:10<00:00,  4.19trial/s, best loss: 544.3629987700928]2022-12-17 17:00:34,567 - build_posterior_wrapper took 0.001004 seconds
# 2022-12-17 17:00:34,568 - TPE using 48/48 trials with best loss 544.362999
# 2022-12-17 17:00:34,578 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 285 to 240.
#  98%|████████████████████████████████████████████████ | 49/50 [00:11<00:00,  3.54trial/s, best loss: 544.3629987700928]2022-12-17 17:00:34,950 - build_posterior_wrapper took 0.002011 seconds
# 2022-12-17 17:00:34,950 - TPE using 49/49 trials with best loss 544.362999
# 100%|█████████████████████████████████████████████████| 50/50 [00:11<00:00,  4.02trial/s, best loss: 544.3629987700928]
# 2022-12-17 17:00:35,037 - LaggedTransformationImplementation - Warning: window size of lagged transformation was changed from 310 to 240.
# 2022-12-17 17:00:35,355 - PipelineTuner - Hyperparameters optimization finished
# 2022-12-17 17:00:35,356 - PipelineTuner - Return tuned pipeline due to the fact that obtained metric 543.593 equal or better than initial (+ 5% deviation) 36808.170
# 2022-12-17 17:00:35,357 - PipelineTuner - Final pipeline: {'depth': 3, 'length': 3, 'nodes': [ridge, custom, lagged]}
# ridge - {'alpha': 8.428811932274613}
# custom - {'a': 55.338343702157225, 'b': 63.48504071749764, 'model_predict': <function domain_model_imitation_predict at 0x0000021C4C45C430>}
# lagged - {'window_size': 240}
# 2022-12-17 17:00:35,358 - PipelineTuner - Final metric: 543.593
# Pipeline structure:
# {'depth': 3, 'length': 3, 'nodes': [ridge, custom, lagged]}
# ridge - {'alpha': 8.428811932274613}
# custom - {'a': 55.338343702157225, 'b': 63.48504071749764, 'model_predict': <function domain_model_imitation_predict at 0x0000021C4C45C430>}
# lagged - {'window_size': 240}

# %% [markdown]
# Thus, we demonstrated the use of imitation of custom model with FEDOT for providing the hybrid approach in composition with AutoML.
