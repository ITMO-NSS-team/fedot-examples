# %% [markdown]
# <center><img src=https://github.com/nccr-itmo/FEDOT/raw/master/docs/fedot_logo.png></img></center>
#
# # <center>Case of multimodal data classification using the [FEDOT](https://github.com/nccr-itmo/FEDOT) framework</center>

# %% [markdown]
# # Introduction

# %% [markdown]
# **FEDOT** is an open source automatic machine learning framework that is capable of automating the creation and optimization of machine learning pipelines and their elements.
# The framework allows you to compactly and efficiently solve various modeling problems.
#
# **Multimodal data** is data that has a different nature (tables, text, images, time series). Humans perceive the world in [a multimodal way](https://en.wikipedia.org/wiki/McGurk_effect), so using this approach in machine learning can also work. Indeed, the sharing of several types of data improves the quality of the model at the expense of information that may be contained in one modality and absent in another.

# %% [markdown]
# ### FEDOT installation

# %% [markdown]
# Let's install the last version of FEDOT

# %%
# !pip install fedot==0.6.1

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Note</b>: there are alternative ways to install the framework and its dependencies, which can be found in the section <b><a href="https://fedot.readthedocs.io/en/latest/introduction/tutorial/quickstart.html">Quickstart</a></b> in our documentation</div>

# %% [markdown]
# ## Data loading

# %% [markdown]
# As an example, let's take the prepared data from the [Wine Reviews](https://www.kaggle.com/datasets/zynicide/wine-reviews) dataset (winemag-data_first150k). For convenience and speed of work, the number of lines and classes has been reduced, no other preprocessing has been carried out (we will leave this to Fedot).
#
# Let's load the data from the repository:

# %%
# !wget https://raw.githubusercontent.com/nccr-itmo/FEDOT/master/examples/data/multimodal_wine.csv
# Out:
# --2023-02-21 12:57:22--  https://raw.githubusercontent.com/nccr-itmo/FEDOT/master/examples/data/multimodal_wine.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 271972 (266K) [text/plain]
# Saving to: ‘multimodal_wine.csv’
#
#
# multimodal_wine.csv   0%[                    ]       0  --.-KB/s
# multimodal_wine.csv 100%[===================>] 265.60K  --.-KB/s    in 0.03s
#
# 2023-02-21 12:57:22 (8.44 MB/s) - ‘multimodal_wine.csv’ saved [271972/271972]

# %% [markdown]
# The **description** field contains a textual description of the different varieties of wine, and the target variable is the **variety** field.

# %%
import pandas as pd

df = pd.read_csv('multimodal_wine.csv')
df
# Out:
#     country                                        description  \
# 0        US  This tremendous 100% varietal wine hails from ...
# 1        US  This spent 20 months in 30% new French oak, an...
# 2        US  This re-named vineyard was formerly bottled as...
# 3        US  The producer sources from two blocks of the vi...
# 4        US  From 18-year-old vines, this supple well-balan...
# ..      ...                                                ...
# 774      US  This is a rich, broad-shouldered Pinot Noir, w...
# 775      US  A delicate, almost fragile wine, this opens wi...
# 776      US  Even with some hours of breathing time, this r...
# 777      US  Loaded with scents and flavors of chocolate, m...
# 778      US  Stewed tomato, graphite and mushrooms in a bro...
#
#                          designation  points  price    province  \
# 0                  Martha's Vineyard      96  235.0  California
# 1                            Reserve      96   65.0      Oregon
# 2                             Silice      95   65.0      Oregon
# 3               Gap's Crown Vineyard      95   60.0  California
# 4    Estate Vineyard Wadensvil Block      95   48.0      Oregon
# ..                               ...     ...    ...         ...
# 774                      Brown Ranch      88   72.0  California
# 775              Arbre Vert Vineyard      88   42.0      Oregon
# 776               La Colina Vineyard      88   60.0      Oregon
# 777                    Shea Vineyard      88   65.0      Oregon
# 778                  Turner Vineyard      88   50.0  California
#
#                region_1           region_2             variety  \
# 0           Napa Valley               Napa  Cabernet Sauvignon
# 1     Willamette Valley  Willamette Valley          Pinot Noir
# 2    Chehalem Mountains  Willamette Valley          Pinot Noir
# 3          Sonoma Coast             Sonoma          Pinot Noir
# 4          Ribbon Ridge  Willamette Valley          Pinot Noir
# ..                  ...                ...                 ...
# 774            Carneros        Napa-Sonoma          Pinot Noir
# 775   Willamette Valley  Willamette Valley          Pinot Noir
# 776        Dundee Hills  Willamette Valley          Pinot Noir
# 777   Willamette Valley  Willamette Valley          Pinot Noir
# 778     Sta. Rita Hills      Central Coast          Pinot Noir
#
#                      winery
# 0                     Heitz
# 1                     Ponzi
# 2                 Bergström
# 3                 Blue Farm
# 4    Patricia Green Cellars
# ..                      ...
# 774              Saintsbury
# 775                  Siduri
# 776               Torii Mor
# 777                    Walt
# 778                    Carr
#
# [779 rows x 10 columns]

# %% [markdown]
# Data has been loaded. Now you can try several solutions.

# %% [markdown]
# ## Using FEDOT's multimodal functionality

# %% [markdown]
# You can solve this classification problem using FEDOT with a few lines of code. First, we import the necessary modules and classes, and also split the selection into train and test parts.
#
# FEDOT will automatically detect the **description** field as a text field and apply various text processing models to it. You should also point out the column with the target variable **variety** and the absence of a separate index column in the data.

# %%
from fedot.api.main import Fedot
from fedot.core.data.data_split import train_test_data_setup
from fedot.core.data.multi_modal import MultiModalData

data = MultiModalData.from_csv(file_path='multimodal_wine.csv', task='classification', target_columns='variety', index_col=None)
fit_data, predict_data = train_test_data_setup(data, shuffle_flag=True, split_ratio=0.7)

# %% [markdown]
# Let's set the parameters of the AutoML model.

# %%
automl_model = Fedot(problem='classification', timeout=10, seed=42)

# %% [markdown]
# * `problem = 'classification'` - problem solved by the framework
# * `timeout = 3` - framework time in minutes
# * `seed = 42` - let's fix the seed for reproducibility
#
# <div class="alert alert-block alert-info"><b>Note</b>: there are also other options for running FEDOT. More details can be found in the section <b><a href="https://fedot.readthedocs.io/en/latest/api/api.html">FEDOT API</a></b> in our documentation.</div>
#
# Next, you can start the process of finding the optimal pipeline and its training. It is necessary to pass data for training to the `.fit()` method.

# %%
automl_model.fit(features=fit_data,
                 target=fit_data.target)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Level 45:root:AssumptionsHandler - Memory consumption for fitting of the initial pipeline in main session: current 192.4 MiB, max: 206.0 MiB
# 2023-02-21 13:01:28,005 - AssumptionsHandler - Memory consumption for fitting of the initial pipeline in main session: current 192.4 MiB, max: 206.0 MiB
# CRITICAL:root:ApiComposer - Initial pipeline was fitted in 2.4 sec.
# 2023-02-21 13:01:28,017 - ApiComposer - Initial pipeline was fitted in 2.4 sec.
# CRITICAL:root:AssumptionsHandler - Preset was changed to best_quality due to fit time estimation for initial model.
# 2023-02-21 13:01:28,026 - AssumptionsHandler - Preset was changed to best_quality due to fit time estimation for initial model.
# CRITICAL:root:ApiComposer - AutoML configured. Parameters tuning: True. Time limit: 10 min. Set of candidate models: ['knn', 'logit', 'normalization', 'rf', 'dt', 'qda', 'poly_features', 'mlp', 'bernb', 'isolation_forest_class', 'lgbm', 'fast_ica', 'pca', 'scaling', 'resample', 'knn', 'logit', 'normalization', 'rf', 'dt', 'qda', 'poly_features', 'mlp', 'bernb', 'isolation_forest_class', 'lgbm', 'fast_ica', 'pca', 'scaling', 'resample'].
# 2023-02-21 13:01:28,043 - ApiComposer - AutoML configured. Parameters tuning: True. Time limit: 10 min. Set of candidate models: ['knn', 'logit', 'normalization', 'rf', 'dt', 'qda', 'poly_features', 'mlp', 'bernb', 'isolation_forest_class', 'lgbm', 'fast_ica', 'pca', 'scaling', 'resample', 'knn', 'logit', 'normalization', 'rf', 'dt', 'qda', 'poly_features', 'mlp', 'bernb', 'isolation_forest_class', 'lgbm', 'fast_ica', 'pca', 'scaling', 'resample'].
# CRITICAL:root:ApiComposer - Pipeline composition started.
# 2023-02-21 13:01:28,064 - ApiComposer - Pipeline composition started.
# Generations:   0%|          | 1/10000 [00:00<?, ?gen/s]CRITICAL:root:GroupedCondition - Optimisation stopped: Time limit is reached
# 2023-02-21 13:07:20,913 - GroupedCondition - Optimisation stopped: Time limit is reached
# Generations:   0%|          | 1/10000 [05:52<?, ?gen/s]
# CRITICAL:root:ApiComposer - Hyperparameters tuning started with 4 min. timeout
# 2023-02-21 13:07:20,955 - ApiComposer - Hyperparameters tuning started with 4 min. timeout
# CRITICAL:root:PipelineTuner - Initial pipeline: {'depth': 3, 'length': 4, 'nodes': [rf, data_source_table, tfidf, data_source_text/description]}
# rf - {'n_jobs': -1}
# data_source_table - {}
# tfidf - {'min_df': 0.005148239293436041, 'max_df': 0.9361463841940135, 'ngram_range': (1, 2)}
# data_source_text/description - {}
# Initial metric: 0.987
# 2023-02-21 13:07:23,315 - PipelineTuner - Initial pipeline: {'depth': 3, 'length': 4, 'nodes': [rf, data_source_table, tfidf, data_source_text/description]}
# rf - {'n_jobs': -1}
# data_source_table - {}
# tfidf - {'min_df': 0.005148239293436041, 'max_df': 0.9361463841940135, 'ngram_range': (1, 2)}
# data_source_text/description - {}
# Initial metric: 0.987
# 100%|██████████| 10/10 [00:53<00:00,  5.34s/trial, best loss: -0.988697]
#   0%|          | 80/100000 [03:08<74:41:29,  2.69s/trial, best loss: -0.991684]
# CRITICAL:root:PipelineTuner - Final pipeline: {'depth': 3, 'length': 4, 'nodes': [rf, data_source_table, tfidf, data_source_text/description]}
# rf - {'n_jobs': -1, 'bootstrap': False, 'criterion': 'gini', 'max_features': 0.09622420420481334, 'min_samples_leaf': 1, 'min_samples_split': 8}
# data_source_table - {}
# tfidf - {'min_df': 0.026548403557843454, 'max_df': 0.9547108243944858, 'ngram_range': (1, 2)}
# data_source_text/description - {}
# 2023-02-21 13:11:27,560 - PipelineTuner - Final pipeline: {'depth': 3, 'length': 4, 'nodes': [rf, data_source_table, tfidf, data_source_text/description]}
# rf - {'n_jobs': -1, 'bootstrap': False, 'criterion': 'gini', 'max_features': 0.09622420420481334, 'min_samples_leaf': 1, 'min_samples_split': 8}
# data_source_table - {}
# tfidf - {'min_df': 0.026548403557843454, 'max_df': 0.9547108243944858, 'ngram_range': (1, 2)}
# data_source_text/description - {}
# CRITICAL:root:PipelineTuner - Final metric: 0.992
# 2023-02-21 13:11:27,577 - PipelineTuner - Final metric: 0.992
# CRITICAL:root:ApiComposer - Hyperparameters tuning finished
# 2023-02-21 13:11:27,586 - ApiComposer - Hyperparameters tuning finished
# CRITICAL:root:ApiComposer - Model generation finished
# 2023-02-21 13:11:27,902 - ApiComposer - Model generation finished
# CRITICAL:root:FEDOT logger - Final pipeline was fitted
# 2023-02-21 13:11:29,905 - FEDOT logger - Final pipeline was fitted
# CRITICAL:root:FEDOT logger - Final pipeline: {'depth': 3, 'length': 4, 'nodes': [rf, data_source_table, tfidf, data_source_text/description]}
# rf - {'n_jobs': -1, 'bootstrap': False, 'criterion': 'gini', 'max_features': 0.09622420420481334, 'min_samples_leaf': 1, 'min_samples_split': 8}
# data_source_table - {}
# tfidf - {'min_df': 0.026548403557843454, 'max_df': 0.9547108243944858, 'ngram_range': (1, 2)}
# data_source_text/description - {}
# 2023-02-21 13:11:29,914 - FEDOT logger - Final pipeline: {'depth': 3, 'length': 4, 'nodes': [rf, data_source_table, tfidf, data_source_text/description]}
# rf - {'n_jobs': -1, 'bootstrap': False, 'criterion': 'gini', 'max_features': 0.09622420420481334, 'min_samples_leaf': 1, 'min_samples_split': 8}
# data_source_table - {}
# tfidf - {'min_df': 0.026548403557843454, 'max_df': 0.9547108243944858, 'ngram_range': (1, 2)}
# data_source_text/description - {}
# Memory consumption for finish in main session: current 202.0 MiB, max: 353.4 MiB
# {'depth': 3, 'length': 4, 'nodes': [rf, data_source_table, tfidf, data_source_text/description]}

# %% [markdown]
# Pipeline's structure in text form is shown above. For visualization, we will use the `.show()` method.

# %%
automl_model.current_pipeline.show(node_size_scale=0.5, dpi=100)

# %% [markdown]
# Let's predict the target variable and compare the metrics.

# %%
prediction = automl_model.predict(predict_data)

metrics = automl_model.get_metrics()

metrics
# Out:
# {'roc_auc': 0.969, 'f1': 0.835}

# %% [markdown]
# Let's visualize the metric.

# %%
automl_model.plot_prediction()

# %% [markdown]
# Let's save the history of the generation process in JSON format.

# %%
automl_model.history.save('multimodal_history.json');

# %% [markdown]
# Using the history, you can look at the change in the value of the metrics for each stage of generation. FEDOT uses evolutionary algorithms and compares the metrics of several individual pipelines in each generation, so the best visualization method is a boxplot, where the middle line means the median value of the metric in a generation.

# %%
automl_model.history.show.fitness_box(best_fraction=0.5, dpi=100)

# %% [markdown]
# You can also look at which specific models dominated the pipelines during the generation process.

# %%
automl_model.history.show.operations_kde(dpi=100)

# %% [markdown]
# ### Baseline

# %% [markdown]
# To compare the quality of the model, we will run FEDOT on the same data, but training only the standard initial pipeline.

# %%
baseline_model = Fedot(problem='classification', seed=42)
baseline_model.fit(features=fit_data,
                 target=fit_data.target,
                 predefined_model='auto')
# Out:
# CRITICAL:root:FEDOT logger - Final pipeline: {'depth': 5, 'length': 8, 'nodes': [rf, rf, scaling, tfidf, data_source_text/description, rf, scaling, data_source_table]}
# rf - {'n_jobs': 1}
# rf - {'n_jobs': 1}
# scaling - {}
# tfidf - {'min_df': 0.1, 'max_df': 0.9}
# data_source_text/description - {}
# rf - {'n_jobs': 1}
# scaling - {}
# data_source_table - {}
# 2023-02-21 13:17:35,081 - FEDOT logger - Final pipeline: {'depth': 5, 'length': 8, 'nodes': [rf, rf, scaling, tfidf, data_source_text/description, rf, scaling, data_source_table]}
# rf - {'n_jobs': 1}
# rf - {'n_jobs': 1}
# scaling - {}
# tfidf - {'min_df': 0.1, 'max_df': 0.9}
# data_source_text/description - {}
# rf - {'n_jobs': 1}
# scaling - {}
# data_source_table - {}
# Memory consumption for finish in main session: current 5.8 MiB, max: 22.7 MiB
# {'depth': 5, 'length': 8, 'nodes': [rf, rf, scaling, tfidf, data_source_text/description, rf, scaling, data_source_table]}

# %% [markdown]
# The `timeout` parameter is not used in this case, so we will remove it. The `predefined_model` parameter specifies that we will not run AutoML, but will simply train the model on the standard initial pipeline.

# %% [markdown]
# Let's visualize the pipeline.

# %%
baseline_model.current_pipeline.show(node_size_scale=0.5, dpi=100)

# %% [markdown]
# Let's get and compare the metrics. It is noticeable that even a small training time significantly improves the quality metrics.

# %%
prediction = baseline_model.predict(predict_data)

baseline_metrics = baseline_model.get_metrics()

baseline_metrics
# Out:
# {'roc_auc': 0.903, 'f1': 0.681}

# %% [markdown]
# ### Tabular data only

# %% [markdown]
# To verify the significance of both modalities, let's train the base model only on tabular data. To do this, simply exclude the **description** text field when loading the data.

# %%
table_data = MultiModalData.from_csv(file_path='multimodal_wine.csv', task='classification', target_columns='variety', 
                                     columns_to_drop=['description'], index_col=None)
table_fit_data, table_predict_data = train_test_data_setup(table_data, shuffle_flag=True, split_ratio=0.7)

# %%
table_model = Fedot(problem='classification', seed=42)
table_model.fit(features=table_fit_data,
                 target=table_fit_data.target,
                 predefined_model='auto')
# Out:
# CRITICAL:root:FEDOT logger - Final pipeline: {'depth': 4, 'length': 4, 'nodes': [rf, rf, scaling, data_source_table]}
# rf - {'n_jobs': 1}
# rf - {'n_jobs': 1}
# scaling - {}
# data_source_table - {}
# 2023-02-21 13:18:02,439 - FEDOT logger - Final pipeline: {'depth': 4, 'length': 4, 'nodes': [rf, rf, scaling, data_source_table]}
# rf - {'n_jobs': 1}
# rf - {'n_jobs': 1}
# scaling - {}
# data_source_table - {}
# Memory consumption for finish in main session: current 5.0 MiB, max: 21.6 MiB
# {'depth': 4, 'length': 4, 'nodes': [rf, rf, scaling, data_source_table]}

# %%
table_model.current_pipeline.show(node_size_scale=0.5, dpi=100)

# %% [markdown]
# It is noticeable that the metrics of this model are noticeably worse than those of the multimodal one.

# %%
prediction = table_model.predict(table_predict_data)

table_metrics = table_model.get_metrics()

table_metrics
# Out:
# {'roc_auc': 0.847, 'f1': 0.673}

# %% [markdown]
# ### Metrics

# %% [markdown]
# Let's compare the metrics of the AutoML model, the multimodal baseline, and the tabular baseline.

# %%
print(f'ROC-AUC of AutoML model is {round(metrics["roc_auc"], 3)}')
print(f'ROC-AUC of baseline model is {round(baseline_metrics["roc_auc"], 3)}')
print(f'ROC-AUC of baseline table model is {round(table_metrics["roc_auc"], 3)}')
# Out:
# ROC-AUC of AutoML model is 0.969
# ROC-AUC of baseline model is 0.903
# ROC-AUC of baseline table model is 0.847

# %%
print(f'F1 of AutoML model is {round(metrics["f1"], 3)}')
print(f'F1 of baseline model is {round(baseline_metrics["f1"], 3)}')
print(f'F1 of baseline table model is {round(table_metrics["f1"], 3)}')
# Out:
# F1 of AutoML model is 0.835
# F1 of baseline model is 0.681
# F1 of baseline table model is 0.673

# %% [markdown]
# ## Afterword

# %% [markdown]
# In this notebook, we showed you how to run the **FEDOT** framework to solve a classification problem using multimodal data using the API. As you can see, this is done quite simply.
#
# Now you can try running the **FEDOT** automatic machine learning framework on your data.
#
# <i class="fa fa-github" style="font-size:24px"></i> - <a href="https://github.com/nccr-itmo/FEDOT"> Our repository </a>
#
# <i class="fa fa-telegram" style="font-size:24px;color:blue"></i> - <a href="https://t.me/FEDOT_helpdesk">Support chat in Telegram</a>
#
# <i class="fa fa-youtube-play" style="font-size:24px;color:red"></i> - <a href="https://www.youtube.com/channel/UC4K9QWaEUpT_p3R4FeDp5jA">Our Youtube channel</a>
